# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load and edit data

# %% [markdown]
# ### Load and edit meta data

# %%
meta_df_1 = pd.read_csv('DDB_PD_117_AMBR_meta_data_export.csv')

# %%
meta_df_1
# Out:
#                            Parent Culture Base Medium  \
# 0     DDB_PD_117_AMBR_DDB35-005_R05_Main_  DDB_BM_016
# 1     DDB_PD_117_AMBR_DDB35-005_R06_Main_  DDB_BM_016
# 2     DDB_PD_117_AMBR_DDB35-005_R07_Main_  DDB_BM_016
# 3     DDB_PD_117_AMBR_DDB35-005_R08_Main_  DDB_BM_016
# 4     DDB_PD_117_AMBR_DDB35-005_R09_Main_  DDB_BM_016
# 5     DDB_PD_117_AMBR_DDB35-005_R10_Main_  DDB_BM_016
# 6   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  DDB_BM_016
# 7   DDB_PD_117_AMBR_HMP3071-003_R12_Main_  DDB_BM_016
# 8   DDB_PD_117_AMBR_HMP3071-003_R13_Main_  DDB_BM_016
# 9   DDB_PD_117_AMBR_HMP3071-003_R14_Main_  DDB_BM_016
# 10  DDB_PD_117_AMBR_HMP3071-003_R15_Main_  DDB_BM_016
# 11  DDB_PD_117_AMBR_HMP3071-003_R16_Main_  DDB_BM_016
#
#    Container ID (calculated) Container Type Control? Culture Type  \
# 0                        R05       AMBR 250       No         Main
# 1                        R06       AMBR 250       No         Main
# 2                        R07       AMBR 250       No         Main
# 3                        R08       AMBR 250       No         Main
# 4                        R09       AMBR 250       No         Main
# 5                        R10       AMBR 250       No         Main
# 6                        R11       AMBR 250       No         Main
# 7                        R12       AMBR 250       No         Main
# 8                        R13       AMBR 250       No         Main
# 9                        R14       AMBR 250       No         Main
# 10                       R15       AMBR 250       No         Main
# 11                       R16       AMBR 250       No         Main
#
#          Experiment Feed Medium #1 Reactor/Plate/Flask Number  Replicate #  \
# 0   DDB_PD_117_AMBR     DDB_FM_015                        R05            1
# 1   DDB_PD_117_AMBR     DDB_FM_015                        R06            1
# 2   DDB_PD_117_AMBR     DDB_FM_015                        R07            1
# 3   DDB_PD_117_AMBR     DDB_FM_015                        R08            1
# 4   DDB_PD_117_AMBR     DDB_FM_015                        R09            1
# 5   DDB_PD_117_AMBR     DDB_FM_015                        R10            1
# 6   DDB_PD_117_AMBR     DDB_FM_015                        R11            1
# 7   DDB_PD_117_AMBR     DDB_FM_015                        R12            1
# 8   DDB_PD_117_AMBR     DDB_FM_015                        R13            1
# 9   DDB_PD_117_AMBR     DDB_FM_015                        R14            1
# 10  DDB_PD_117_AMBR     DDB_FM_015                        R15            1
# 11  DDB_PD_117_AMBR     DDB_FM_015                        R16            1
#
#     ... Culture Volume Unit Temperature Setpoint (C)  \
# 0   ...                  mL                       30
# 1   ...                  mL                       30
# 2   ...                  mL                       30
# 3   ...                  mL                       30
# 4   ...                  mL                       30
# 5   ...                  mL                       30
# 6   ...                  mL                       30
# 7   ...                  mL                       30
# 8   ...                  mL                       30
# 9   ...                  mL                       30
# 10  ...                  mL                       30
# 11  ...                  mL                       30
#
#                      Feed #1 Profile pH Setpoint  pH Control Base Solution  \
# 0   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 1   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 2   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 3   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 4   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 5   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 6   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 7   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 8   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 9   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 10  DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 11  DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
#
#    Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0                     0.15                     0.15
# 1                     0.15                     0.15
# 2                     0.15                     0.15
# 3                     0.15                     0.15
# 4                     0.15                     0.15
# 5                     0.15                     0.15
# 6                     0.15                     0.15
# 7                     0.15                     0.15
# 8                     0.15                     0.15
# 9                     0.15                     0.15
# 10                    0.15                     0.15
# 11                    0.15                     0.15
#
#    Minimum Stirring or Shaking Speed (rpm)  \
# 0                                     4000
# 1                                     4000
# 2                                     4000
# 3                                     4000
# 4                                     4000
# 5                                     4000
# 6                                     4000
# 7                                     4000
# 8                                     4000
# 9                                     4000
# 10                                    4000
# 11                                    4000
#
#     Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type
# 0                                      4000                Air
# 1                                      4000                Air
# 2                                      4000                Air
# 3                                      4000                Air
# 4                                      4000                Air
# 5                                      4000                Air
# 6                                      4000                Air
# 7                                      4000                Air
# 8                                      4000                Air
# 9                                      4000                Air
# 10                                     4000                Air
# 11                                     4000                Air
#
# [12 rows x 23 columns]

# %%
meta_df_1['Condition'] = ['control','control','control','scale-down','scale-down','scale-down','control','control','control','scale-down','scale-down','scale-down']

# %%
meta_df_1['Strain Batch']
# Out:
# 0       DDB35-005
# 1       DDB35-005
# 2       DDB35-005
# 3       DDB35-005
# 4       DDB35-005
# 5       DDB35-005
# 6     HMP3071-003
# 7     HMP3071-003
# 8     HMP3071-003
# 9     HMP3071-003
# 10    HMP3071-003
# 11    HMP3071-003
# Name: Strain Batch, dtype: object

# %%
meta_df_2 = pd.read_csv('DDB_PD_126_AMBR_meta_data_export.csv')

# %%
meta_df_2
# Out:
#                            Parent Culture Base Medium  \
# 0   DDB_PD_126_AMBR_HMP3071-003_R05_Main_  DDB_BM_016
# 1   DDB_PD_126_AMBR_HMP3071-003_R06_Main_  DDB_BM_016
# 2   DDB_PD_126_AMBR_HMP3071-003_R07_Main_  DDB_BM_016
# 3   DDB_PD_126_AMBR_HMP3071-003_R08_Main_  DDB_BM_016
# 4   DDB_PD_126_AMBR_HMP3071-003_R09_Main_  DDB_BM_016
# 5   DDB_PD_126_AMBR_HMP3071-003_R10_Main_  DDB_BM_016
# 6    DDB_PD_126_AMBR_SDT714-001_R11_Main_  DDB_BM_016
# 7    DDB_PD_126_AMBR_SDT714-001_R12_Main_  DDB_BM_016
# 8    DDB_PD_126_AMBR_SDT714-001_R13_Main_  DDB_BM_016
# 9    DDB_PD_126_AMBR_SDT714-001_R14_Main_  DDB_BM_016
# 10   DDB_PD_126_AMBR_SDT714-001_R15_Main_  DDB_BM_016
# 11   DDB_PD_126_AMBR_SDT714-001_R16_Main_  DDB_BM_016
#
#    Container ID (calculated) Container Type Culture Type       Experiment  \
# 0                        R05       AMBR 250         Main  DDB_PD_126_AMBR
# 1                        R06       AMBR 250         Main  DDB_PD_126_AMBR
# 2                        R07       AMBR 250         Main  DDB_PD_126_AMBR
# 3                        R08       AMBR 250         Main  DDB_PD_126_AMBR
# 4                        R09       AMBR 250         Main  DDB_PD_126_AMBR
# 5                        R10       AMBR 250         Main  DDB_PD_126_AMBR
# 6                        R11       AMBR 250         Main  DDB_PD_126_AMBR
# 7                        R12       AMBR 250         Main  DDB_PD_126_AMBR
# 8                        R13       AMBR 250         Main  DDB_PD_126_AMBR
# 9                        R14       AMBR 250         Main  DDB_PD_126_AMBR
# 10                       R15       AMBR 250         Main  DDB_PD_126_AMBR
# 11                       R16       AMBR 250         Main  DDB_PD_126_AMBR
#
#    Feed Medium #1 Reactor/Plate/Flask Number  Replicate #  \
# 0      DDB_FM_016                        R05            1
# 1      DDB_FM_016                        R06            1
# 2      DDB_FM_016                        R07            1
# 3      DDB_FM_016                        R08            1
# 4      DDB_FM_016                        R09            1
# 5      DDB_FM_016                        R10            1
# 6      DDB_FM_016                        R11            1
# 7      DDB_FM_016                        R12            1
# 8      DDB_FM_016                        R13            1
# 9      DDB_FM_016                        R14            1
# 10     DDB_FM_016                        R15            1
# 11     DDB_FM_016                        R16            1
#
#                                         Seed  ... pH Control Base Solution  \
# 0   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 1   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 2   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 3   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 4   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 5   DDB_PD_126_AMBR_HMP3071-003_2_Pre-Final_  ...    Ammonium hydroxide 8%
# 6    DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
# 7    DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
# 8    DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
# 9    DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
# 10   DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
# 11   DDB_PD_126_AMBR_SDT714-001_1_Pre-Final_  ...    Ammonium hydroxide 8%
#
#     DO Control Setpoint (%) DO Control Cascade Level 1  \
# 0                        40                   Stirring
# 1                        40                   Stirring
# 2                        40                   Stirring
# 3                        40                   Stirring
# 4                        40                   Stirring
# 5                        40                   Stirring
# 6                        40                   Stirring
# 7                        40                   Stirring
# 8                        40                   Stirring
# 9                        40                   Stirring
# 10                       40                   Stirring
# 11                       40                   Stirring
#
#     DO Control Cascade Level 2  DO Control Cascade Level 3  \
# 0                     Aeration                      Oxygen
# 1                     Aeration                      Oxygen
# 2                     Aeration                      Oxygen
# 3                     Aeration                      Oxygen
# 4                     Aeration                      Oxygen
# 5                     Aeration                      Oxygen
# 6                     Aeration                      Oxygen
# 7                     Aeration                      Oxygen
# 8                     Aeration                      Oxygen
# 9                     Aeration                      Oxygen
# 10                    Aeration                      Oxygen
# 11                    Aeration                      Oxygen
#
#    Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0                      0.1                     0.25
# 1                      0.1                     0.25
# 2                      0.1                     0.25
# 3                      0.1                     0.25
# 4                      0.1                     0.25
# 5                      0.1                     0.25
# 6                      0.1                     0.25
# 7                      0.1                     0.25
# 8                      0.1                     0.25
# 9                      0.1                     0.25
# 10                     0.1                     0.25
# 11                     0.1                     0.25
#
#    Minimum Stirring or Shaking Speed (rpm)  \
# 0                                     1000
# 1                                     1000
# 2                                     1000
# 3                                     1000
# 4                                     1000
# 5                                     1000
# 6                                     1000
# 7                                     1000
# 8                                     1000
# 9                                     1000
# 10                                    1000
# 11                                    1000
#
#    Maximum Stirring or Shaking Speed (rpm) Aeration Gas Type
# 0                                     4000               Air
# 1                                     4000               Air
# 2                                     4000               Air
# 3                                     4000               Air
# 4                                     4000               Air
# 5                                     4000               Air
# 6                                     4000               Air
# 7                                     4000               Air
# 8                                     4000               Air
# 9                                     4000               Air
# 10                                    4000               Air
# 11                                    4000               Air
#
# [12 rows x 25 columns]

# %%
meta_df_2['Condition'] = ['control','control','control','scale-down','scale-down','scale-down','control','control','control','scale-down','scale-down','scale-down']

# %%
meta_df =pd.concat([meta_df_1,meta_df_2]).reset_index().drop('index',axis=1)
meta_df
# Out:
#                            Parent Culture Base Medium  \
# 0     DDB_PD_117_AMBR_DDB35-005_R05_Main_  DDB_BM_016
# 1     DDB_PD_117_AMBR_DDB35-005_R06_Main_  DDB_BM_016
# 2     DDB_PD_117_AMBR_DDB35-005_R07_Main_  DDB_BM_016
# 3     DDB_PD_117_AMBR_DDB35-005_R08_Main_  DDB_BM_016
# 4     DDB_PD_117_AMBR_DDB35-005_R09_Main_  DDB_BM_016
# 5     DDB_PD_117_AMBR_DDB35-005_R10_Main_  DDB_BM_016
# 6   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  DDB_BM_016
# 7   DDB_PD_117_AMBR_HMP3071-003_R12_Main_  DDB_BM_016
# 8   DDB_PD_117_AMBR_HMP3071-003_R13_Main_  DDB_BM_016
# 9   DDB_PD_117_AMBR_HMP3071-003_R14_Main_  DDB_BM_016
# 10  DDB_PD_117_AMBR_HMP3071-003_R15_Main_  DDB_BM_016
# 11  DDB_PD_117_AMBR_HMP3071-003_R16_Main_  DDB_BM_016
# 12  DDB_PD_126_AMBR_HMP3071-003_R05_Main_  DDB_BM_016
# 13  DDB_PD_126_AMBR_HMP3071-003_R06_Main_  DDB_BM_016
# 14  DDB_PD_126_AMBR_HMP3071-003_R07_Main_  DDB_BM_016
# 15  DDB_PD_126_AMBR_HMP3071-003_R08_Main_  DDB_BM_016
# 16  DDB_PD_126_AMBR_HMP3071-003_R09_Main_  DDB_BM_016
# 17  DDB_PD_126_AMBR_HMP3071-003_R10_Main_  DDB_BM_016
# 18   DDB_PD_126_AMBR_SDT714-001_R11_Main_  DDB_BM_016
# 19   DDB_PD_126_AMBR_SDT714-001_R12_Main_  DDB_BM_016
# 20   DDB_PD_126_AMBR_SDT714-001_R13_Main_  DDB_BM_016
# 21   DDB_PD_126_AMBR_SDT714-001_R14_Main_  DDB_BM_016
# 22   DDB_PD_126_AMBR_SDT714-001_R15_Main_  DDB_BM_016
# 23   DDB_PD_126_AMBR_SDT714-001_R16_Main_  DDB_BM_016
#
#    Container ID (calculated) Container Type Control? Culture Type  \
# 0                        R05       AMBR 250       No         Main
# 1                        R06       AMBR 250       No         Main
# 2                        R07       AMBR 250       No         Main
# 3                        R08       AMBR 250       No         Main
# 4                        R09       AMBR 250       No         Main
# 5                        R10       AMBR 250       No         Main
# 6                        R11       AMBR 250       No         Main
# 7                        R12       AMBR 250       No         Main
# 8                        R13       AMBR 250       No         Main
# 9                        R14       AMBR 250       No         Main
# 10                       R15       AMBR 250       No         Main
# 11                       R16       AMBR 250       No         Main
# 12                       R05       AMBR 250      NaN         Main
# 13                       R06       AMBR 250      NaN         Main
# 14                       R07       AMBR 250      NaN         Main
# 15                       R08       AMBR 250      NaN         Main
# 16                       R09       AMBR 250      NaN         Main
# 17                       R10       AMBR 250      NaN         Main
# 18                       R11       AMBR 250      NaN         Main
# 19                       R12       AMBR 250      NaN         Main
# 20                       R13       AMBR 250      NaN         Main
# 21                       R14       AMBR 250      NaN         Main
# 22                       R15       AMBR 250      NaN         Main
# 23                       R16       AMBR 250      NaN         Main
#
#          Experiment Feed Medium #1 Reactor/Plate/Flask Number  Replicate #  \
# 0   DDB_PD_117_AMBR     DDB_FM_015                        R05            1
# 1   DDB_PD_117_AMBR     DDB_FM_015                        R06            1
# 2   DDB_PD_117_AMBR     DDB_FM_015                        R07            1
# 3   DDB_PD_117_AMBR     DDB_FM_015                        R08            1
# 4   DDB_PD_117_AMBR     DDB_FM_015                        R09            1
# 5   DDB_PD_117_AMBR     DDB_FM_015                        R10            1
# 6   DDB_PD_117_AMBR     DDB_FM_015                        R11            1
# 7   DDB_PD_117_AMBR     DDB_FM_015                        R12            1
# 8   DDB_PD_117_AMBR     DDB_FM_015                        R13            1
# 9   DDB_PD_117_AMBR     DDB_FM_015                        R14            1
# 10  DDB_PD_117_AMBR     DDB_FM_015                        R15            1
# 11  DDB_PD_117_AMBR     DDB_FM_015                        R16            1
# 12  DDB_PD_126_AMBR     DDB_FM_016                        R05            1
# 13  DDB_PD_126_AMBR     DDB_FM_016                        R06            1
# 14  DDB_PD_126_AMBR     DDB_FM_016                        R07            1
# 15  DDB_PD_126_AMBR     DDB_FM_016                        R08            1
# 16  DDB_PD_126_AMBR     DDB_FM_016                        R09            1
# 17  DDB_PD_126_AMBR     DDB_FM_016                        R10            1
# 18  DDB_PD_126_AMBR     DDB_FM_016                        R11            1
# 19  DDB_PD_126_AMBR     DDB_FM_016                        R12            1
# 20  DDB_PD_126_AMBR     DDB_FM_016                        R13            1
# 21  DDB_PD_126_AMBR     DDB_FM_016                        R14            1
# 22  DDB_PD_126_AMBR     DDB_FM_016                        R15            1
# 23  DDB_PD_126_AMBR     DDB_FM_016                        R16            1
#
#     ... Minimum Aeration (slpm) Maximum Aeration (slpm)  \
# 0   ...                    0.15                    0.15
# 1   ...                    0.15                    0.15
# 2   ...                    0.15                    0.15
# 3   ...                    0.15                    0.15
# 4   ...                    0.15                    0.15
# 5   ...                    0.15                    0.15
# 6   ...                    0.15                    0.15
# 7   ...                    0.15                    0.15
# 8   ...                    0.15                    0.15
# 9   ...                    0.15                    0.15
# 10  ...                    0.15                    0.15
# 11  ...                    0.15                    0.15
# 12  ...                    0.10                    0.25
# 13  ...                    0.10                    0.25
# 14  ...                    0.10                    0.25
# 15  ...                    0.10                    0.25
# 16  ...                    0.10                    0.25
# 17  ...                    0.10                    0.25
# 18  ...                    0.10                    0.25
# 19  ...                    0.10                    0.25
# 20  ...                    0.10                    0.25
# 21  ...                    0.10                    0.25
# 22  ...                    0.10                    0.25
# 23  ...                    0.10                    0.25
#
#     Minimum Stirring or Shaking Speed (rpm)  \
# 0                                      4000
# 1                                      4000
# 2                                      4000
# 3                                      4000
# 4                                      4000
# 5                                      4000
# 6                                      4000
# 7                                      4000
# 8                                      4000
# 9                                      4000
# 10                                     4000
# 11                                     4000
# 12                                     1000
# 13                                     1000
# 14                                     1000
# 15                                     1000
# 16                                     1000
# 17                                     1000
# 18                                     1000
# 19                                     1000
# 20                                     1000
# 21                                     1000
# 22                                     1000
# 23                                     1000
#
#    Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type   Condition  \
# 0                                     4000                Air     control
# 1                                     4000                Air     control
# 2                                     4000                Air     control
# 3                                     4000                Air  scale-down
# 4                                     4000                Air  scale-down
# 5                                     4000                Air  scale-down
# 6                                     4000                Air     control
# 7                                     4000                Air     control
# 8                                     4000                Air     control
# 9                                     4000                Air  scale-down
# 10                                    4000                Air  scale-down
# 11                                    4000                Air  scale-down
# 12                                    4000                Air     control
# 13                                    4000                Air     control
# 14                                    4000                Air     control
# 15                                    4000                Air  scale-down
# 16                                    4000                Air  scale-down
# 17                                    4000                Air  scale-down
# 18                                    4000                Air     control
# 19                                    4000                Air     control
# 20                                    4000                Air     control
# 21                                    4000                Air  scale-down
# 22                                    4000                Air  scale-down
# 23                                    4000                Air  scale-down
#
#     DO Control Setpoint (%) DO Control Cascade Level 1  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# 5                       NaN                        NaN
# 6                       NaN                        NaN
# 7                       NaN                        NaN
# 8                       NaN                        NaN
# 9                       NaN                        NaN
# 10                      NaN                        NaN
# 11                      NaN                        NaN
# 12                     40.0                   Stirring
# 13                     40.0                   Stirring
# 14                     40.0                   Stirring
# 15                     40.0                   Stirring
# 16                     40.0                   Stirring
# 17                     40.0                   Stirring
# 18                     40.0                   Stirring
# 19                     40.0                   Stirring
# 20                     40.0                   Stirring
# 21                     40.0                   Stirring
# 22                     40.0                   Stirring
# 23                     40.0                   Stirring
#
#     DO Control Cascade Level 2  DO Control Cascade Level 3
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                          NaN                         NaN
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                    Aeration                      Oxygen
# 13                    Aeration                      Oxygen
# 14                    Aeration                      Oxygen
# 15                    Aeration                      Oxygen
# 16                    Aeration                      Oxygen
# 17                    Aeration                      Oxygen
# 18                    Aeration                      Oxygen
# 19                    Aeration                      Oxygen
# 20                    Aeration                      Oxygen
# 21                    Aeration                      Oxygen
# 22                    Aeration                      Oxygen
# 23                    Aeration                      Oxygen
#
# [24 rows x 28 columns]

# %%
# removing the strain DDB35, because it does not belong to this study
meta_df = meta_df[~meta_df["Strain Batch"].str.contains("DDB35")]

# %% [markdown]
# ### Load online data

# %%
online_df_1 = pd.read_csv('DDB_PD_117_AMBR_online_data_export.csv')

# %%
online_df_2 = pd.read_csv('DDB_PD_126_AMBR_online_data_export.csv')

# %%
online_df = pd.concat([online_df_1,online_df_2])
online_df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0        0.0000  99.384914  6.529322    1002.000000    29.989540  0.547836
# 1        0.0025  98.465270  6.534555    1002.000000    29.982064  2.383883
# 2        0.0050  97.813961  6.535457     998.741950    29.974569  2.806834
# 3        0.0075  97.375563  6.534708     998.048215    29.969999  2.727807
# 4        0.0100  97.116550  6.534041    1003.000000    29.969591  2.704525
# ...         ...        ...       ...            ...          ...       ...
# 392407  81.6625  -0.225624  6.447796     500.068040    29.935918  1.296619
# 392408  81.6650  -0.243608  6.445576     500.808036    29.891517  1.270719
# 392409  81.6675  -0.251021  6.443884     499.325514    29.840928  1.280745
# 392410  81.6700  -0.254470  6.442383     498.925096    29.788414  1.309418
# 392411  81.6725  -0.257820  6.440824     500.824483    29.734734  1.336979
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0       100.050691     0.000000         20.95  20.702183  ...
# 1        99.785299     0.000000         20.95  20.705174  ...
# 2        99.817884     0.000000         20.95  20.708171  ...
# 3        99.954108     0.000000         20.95  20.707951  ...
# 4       100.064567     0.000000         20.95  20.702877  ...
# ...            ...          ...           ...        ...  ...
# 392407    0.000000     9.955355        100.00  16.039389  ...
# 392408    0.000000    10.002715        100.00  16.032728  ...
# 392409    0.000000    10.008860        100.00  16.024302  ...
# 392410    0.000000    10.016026        100.00  16.014374  ...
# 392411    0.000000    10.041772        100.00  16.003385  ...
#
#         Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0                          0.15                     0.15
# 1                          0.15                     0.15
# 2                          0.15                     0.15
# 3                          0.15                     0.15
# 4                          0.15                     0.15
# ...                         ...                      ...
# 392407                     0.10                     0.25
# 392408                     0.10                     0.25
# 392409                     0.10                     0.25
# 392410                     0.10                     0.25
# 392411                     0.10                     0.25
#
#         Minimum Stirring or Shaking Speed (rpm)  \
# 0                                          4000
# 1                                          4000
# 2                                          4000
# 3                                          4000
# 4                                          4000
# ...                                         ...
# 392407                                     1000
# 392408                                     1000
# 392409                                     1000
# 392410                                     1000
# 392411                                     1000
#
#         Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type  Phase  \
# 0                                          4000                Air  batch
# 1                                          4000                Air  batch
# 2                                          4000                Air  batch
# 3                                          4000                Air  batch
# 4                                          4000                Air  batch
# ...                                         ...                ...    ...
# 392407                                     4000                Air   feed
# 392408                                     4000                Air   feed
# 392409                                     4000                Air   feed
# 392410                                     4000                Air   feed
# 392411                                     4000                Air   feed
#
#         DO Control Setpoint (%)  DO Control Cascade Level 1  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 392407                     40.0                    Stirring
# 392408                     40.0                    Stirring
# 392409                     40.0                    Stirring
# 392410                     40.0                    Stirring
# 392411                     40.0                    Stirring
#
#         DO Control Cascade Level 2  DO Control Cascade Level 3
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 392407                    Aeration                      Oxygen
# 392408                    Aeration                      Oxygen
# 392409                    Aeration                      Oxygen
# 392410                    Aeration                      Oxygen
# 392411                    Aeration                      Oxygen
#
# [760267 rows x 52 columns]

# %%
# removing the strain DDB35, because it does not belong to this study
online_df = online_df[~online_df["Strain Batch"].str.contains("DDB35")]

# %% [markdown]
# ### Load and edit offline data

# %%
offline_df_1 = pd.read_csv('DDB_PD_117_AMBR_offline_data_export.csv')

# %%
offline_df_2 = pd.read_csv('DDB_PD_126_AMBR_offline_data_export.csv')

# %%
offline_df = pd.concat([offline_df_1,offline_df_2]).reset_index().drop('index',axis=1)

# %%
# removing the strain DDB35, because it does not belong to this study
offline_df = offline_df[~offline_df["Parent Culture"].str.contains("DDB35")]

# %%
# merge with metadata to filter by when plotting
offline_df = pd.merge(left=offline_df,right=meta_df[['Parent Culture','Strain Batch','Condition']],how='left')

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df
# Out:
#                            Parent Culture  batch_end
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_    16.8600
# 1   DDB_PD_117_AMBR_HMP3071-003_R12_Main_    16.5400
# 2   DDB_PD_117_AMBR_HMP3071-003_R13_Main_    16.6625
# 3   DDB_PD_117_AMBR_HMP3071-003_R14_Main_    16.5550
# 4   DDB_PD_117_AMBR_HMP3071-003_R15_Main_    16.6725
# 5   DDB_PD_117_AMBR_HMP3071-003_R16_Main_    16.8025
# 6   DDB_PD_126_AMBR_HMP3071-003_R05_Main_    18.9550
# 7   DDB_PD_126_AMBR_HMP3071-003_R06_Main_    18.8625
# 8   DDB_PD_126_AMBR_HMP3071-003_R07_Main_    19.1675
# 9   DDB_PD_126_AMBR_HMP3071-003_R08_Main_    19.0050
# 10  DDB_PD_126_AMBR_HMP3071-003_R09_Main_    19.1850
# 11  DDB_PD_126_AMBR_HMP3071-003_R10_Main_    18.8850
# 12   DDB_PD_126_AMBR_SDT714-001_R11_Main_    20.6200
# 13   DDB_PD_126_AMBR_SDT714-001_R12_Main_    20.0650
# 14   DDB_PD_126_AMBR_SDT714-001_R13_Main_    20.3100
# 15   DDB_PD_126_AMBR_SDT714-001_R14_Main_    19.8300
# 16   DDB_PD_126_AMBR_SDT714-001_R15_Main_    20.3850
# 17   DDB_PD_126_AMBR_SDT714-001_R16_Main_    20.9975

# %%
# merge batch end times into offlien data
offline_df = pd.merge(left=offline_df,right=batch_end_df,how='left')
offline_df['feed_time'] = offline_df['Timepoint (h)'] - offline_df['batch_end']

# %%
# avergae timepoints between biological replicates
avergae_timepoint_df = offline_df[['Strain Batch','Timepoint (#)','Condition','Timepoint (h)']].groupby(
    by=['Strain Batch','Timepoint (#)','Condition'],
    as_index=False
).mean()
avergae_timepoint_df.rename(columns={"Timepoint (h)": "Average Timepoint (h)"},inplace=True)
avergae_timepoint_df[avergae_timepoint_df['Strain Batch'] == 'SDT714-001']
# Out:
#    Strain Batch Timepoint (#)   Condition  Average Timepoint (h)
# 10   SDT714-001           S01     control              12.373066
# 11   SDT714-001           S01  scale-down              12.518637
# 12   SDT714-001           S02     control              20.264654
# 13   SDT714-001           S02  scale-down              20.346427
# 14   SDT714-001           S03     control              40.303510
# 15   SDT714-001           S03  scale-down              40.388159
# 16   SDT714-001           S04     control              60.300772
# 17   SDT714-001           S04  scale-down              60.390491
# 18   SDT714-001           S05     control              80.300676
# 19   SDT714-001           S05  scale-down              80.388916

# %%
avergae_timepoint_df['Strain Batch'].unique()
# Out:
# array(['HMP3071-003', 'SDT714-001'], dtype=object)

# %%
# merge averaged timepoints into offline data
offline_df = pd.merge(left=offline_df,right=avergae_timepoint_df,how='left')

# %%
# average timepoint from feed start (batch end time subtracted) between biological replicates
avergae_feed_timepoint_df = offline_df[['Strain Batch','Timepoint (#)','Condition','feed_time']].groupby(
    by=['Strain Batch','Timepoint (#)','Condition'],
    as_index=False
).mean()
avergae_feed_timepoint_df.rename(columns={"feed_time": "average_feed_time"},inplace=True)

# %%
# merge averaged timepoints from feed start into offline data
offline_df = pd.merge(left=offline_df,right=avergae_feed_timepoint_df,how='left')

# %%
# average technical replicates of cell dry weight
offline_df['CDW_avg [g/L]'] = offline_df[['CDW_1 [g/L]','CDW_2 [g/L]','CDW_3 [g/L]']].mean(axis=1)

# %%
offline_df
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  CDW_3 [g/L]  Ammonium [g/L]  lactose [g/L]  \
# 0            0.426389  ...     2.500000             NaN            NaN
# 1            0.000000  ...     9.300000             NaN            NaN
# 2            0.000000  ...          NaN             NaN            NaN
# 3            0.354635  ...    33.000000             NaN            NaN
# 4            0.910389  ...    52.700000        1.830674            NaN
# ..                ...  ...          ...             ...            ...
# 85           0.321480  ...     0.300000             NaN            0.0
# 86           0.080446  ...     6.900000             NaN            0.0
# 87           0.062385  ...    15.333333             NaN            0.0
# 88           0.460868  ...    30.900000             NaN            0.0
# 89           1.054493  ...    48.500000             NaN            0.0
#
#     Strain Batch   Condition  batch_end  feed_time  Average Timepoint (h)  \
# 0    HMP3071-003     control    16.8600  -4.583343              12.265609
# 1    HMP3071-003     control    16.8600  -0.080744              17.756268
# 2    HMP3071-003     control    16.8600  19.986045              37.825127
# 3    HMP3071-003     control    16.8600  40.109901              57.856183
# 4    HMP3071-003     control    16.8600  60.148533              77.878086
# ..           ...         ...        ...        ...                    ...
# 85    SDT714-001  scale-down    20.9975  -8.431126              12.518637
# 86    SDT714-001  scale-down    20.9975  -0.058928              20.346427
# 87    SDT714-001  scale-down    20.9975  19.983857              40.388159
# 88    SDT714-001  scale-down    20.9975  39.984344              60.390491
# 89    SDT714-001  scale-down    20.9975  59.982682              80.388916
#
#     average_feed_time  CDW_avg [g/L]
# 0           -5.575641       2.700000
# 1           -0.084982       9.433333
# 2           19.983877      21.625000
# 3           40.014933      33.266667
# 4           60.036836      52.566667
# ..                ...            ...
# 85          -7.885530       0.300000
# 86          -0.057740       6.533333
# 87          19.983993      15.777778
# 88          39.986324      32.433333
# 89          59.984749      47.800000
#
# [90 rows x 30 columns]

# %% [markdown]
# ### Edit online data

# %% [markdown]
# One of my problems here is, that the reactors seem to have been fed slightly different amounts of feed volume

# %% [markdown]
# #### Subtracting batch end time

# %%
# merge with metadata to filter by when plotting
online_df = pd.merge(left=online_df,right=meta_df[['Parent Culture','Strain Batch','Condition']],how='left')
# need to fill nan feed volumes with 0 in online data
online_df['Feed_volume'] = online_df['Feed_volume'].fillna(0)

# %%
online_df['Condition'].unique()
# Out:
# array(['control', 'scale-down'], dtype=object)

# %%
online_df.groupby(['Strain Batch','Condition','Parent Culture'])['CTR'].mean()
# Out:
# Strain Batch  Condition   Parent Culture
# HMP3071-003   control     DDB_PD_117_AMBR_HMP3071-003_R11_Main_     9.923237
#                           DDB_PD_117_AMBR_HMP3071-003_R12_Main_     9.452780
#                           DDB_PD_117_AMBR_HMP3071-003_R13_Main_     9.234457
#                           DDB_PD_126_AMBR_HMP3071-003_R05_Main_     9.069720
#                           DDB_PD_126_AMBR_HMP3071-003_R06_Main_     9.189429
#                           DDB_PD_126_AMBR_HMP3071-003_R07_Main_     9.070046
#               scale-down  DDB_PD_117_AMBR_HMP3071-003_R14_Main_     9.720955
#                           DDB_PD_117_AMBR_HMP3071-003_R15_Main_    10.167680
#                           DDB_PD_117_AMBR_HMP3071-003_R16_Main_    10.367931
#                           DDB_PD_126_AMBR_HMP3071-003_R08_Main_    10.113895
#                           DDB_PD_126_AMBR_HMP3071-003_R09_Main_     9.932179
#                           DDB_PD_126_AMBR_HMP3071-003_R10_Main_     9.822200
# SDT714-001    control     DDB_PD_126_AMBR_SDT714-001_R11_Main_      9.282707
#                           DDB_PD_126_AMBR_SDT714-001_R12_Main_      9.204323
#                           DDB_PD_126_AMBR_SDT714-001_R13_Main_      8.926701
#               scale-down  DDB_PD_126_AMBR_SDT714-001_R14_Main_      9.345002
#                           DDB_PD_126_AMBR_SDT714-001_R15_Main_      9.595000
#                           DDB_PD_126_AMBR_SDT714-001_R16_Main_      9.420460
# Name: CTR, dtype: float64

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df
# Out:
#                            Parent Culture  batch_end
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_    16.8600
# 1   DDB_PD_117_AMBR_HMP3071-003_R12_Main_    16.5400
# 2   DDB_PD_117_AMBR_HMP3071-003_R13_Main_    16.6625
# 3   DDB_PD_117_AMBR_HMP3071-003_R14_Main_    16.5550
# 4   DDB_PD_117_AMBR_HMP3071-003_R15_Main_    16.6725
# 5   DDB_PD_117_AMBR_HMP3071-003_R16_Main_    16.8025
# 6   DDB_PD_126_AMBR_HMP3071-003_R05_Main_    18.9550
# 7   DDB_PD_126_AMBR_HMP3071-003_R06_Main_    18.8625
# 8   DDB_PD_126_AMBR_HMP3071-003_R07_Main_    19.1675
# 9   DDB_PD_126_AMBR_HMP3071-003_R08_Main_    19.0050
# 10  DDB_PD_126_AMBR_HMP3071-003_R09_Main_    19.1850
# 11  DDB_PD_126_AMBR_HMP3071-003_R10_Main_    18.8850
# 12   DDB_PD_126_AMBR_SDT714-001_R11_Main_    20.6200
# 13   DDB_PD_126_AMBR_SDT714-001_R12_Main_    20.0650
# 14   DDB_PD_126_AMBR_SDT714-001_R13_Main_    20.3100
# 15   DDB_PD_126_AMBR_SDT714-001_R14_Main_    19.8300
# 16   DDB_PD_126_AMBR_SDT714-001_R15_Main_    20.3850
# 17   DDB_PD_126_AMBR_SDT714-001_R16_Main_    20.9975

# %%
# merge batch end times into online data
online_df = pd.merge(left=online_df,right=batch_end_df,how='left')
online_df['feed_time'] = online_df['Time'] - online_df['batch_end']

# %%
# round values
online_df['feed_time'] = np.round(online_df['feed_time'].values,4)

# %% [markdown]
# #### Cutting data based on time of last shared feed volume

# %%
feed_vol_end_df = online_df.groupby('Parent Culture')['Feed_volume'].max().reset_index()
feed_vol_end_df
# Out:
#                            Parent Culture  Feed_volume
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_    64.940700
# 1   DDB_PD_117_AMBR_HMP3071-003_R12_Main_    64.919746
# 2   DDB_PD_117_AMBR_HMP3071-003_R13_Main_    64.916907
# 3   DDB_PD_117_AMBR_HMP3071-003_R14_Main_    65.119385
# 4   DDB_PD_117_AMBR_HMP3071-003_R15_Main_    65.052244
# 5   DDB_PD_117_AMBR_HMP3071-003_R16_Main_    65.008944
# 6   DDB_PD_126_AMBR_HMP3071-003_R05_Main_    64.474039
# 7   DDB_PD_126_AMBR_HMP3071-003_R06_Main_    64.421722
# 8   DDB_PD_126_AMBR_HMP3071-003_R07_Main_    63.449477
# 9   DDB_PD_126_AMBR_HMP3071-003_R08_Main_    63.900393
# 10  DDB_PD_126_AMBR_HMP3071-003_R09_Main_    63.351951
# 11  DDB_PD_126_AMBR_HMP3071-003_R10_Main_    64.314924
# 12   DDB_PD_126_AMBR_SDT714-001_R11_Main_    64.317806
# 13   DDB_PD_126_AMBR_SDT714-001_R12_Main_    66.083623
# 14   DDB_PD_126_AMBR_SDT714-001_R13_Main_    65.263230
# 15   DDB_PD_126_AMBR_SDT714-001_R14_Main_    66.763542
# 16   DDB_PD_126_AMBR_SDT714-001_R15_Main_    64.944511
# 17   DDB_PD_126_AMBR_SDT714-001_R16_Main_    63.048406

# %%
# cutting with feed volume data greater than the last shared value
online_df = online_df[~(online_df['Feed_volume'] > feed_vol_end_df['Feed_volume'].min())]

# %%
feed_end_df = online_df.groupby('Parent Culture')['feed_time'].max().reset_index()
feed_end_df
# Out:
#                            Parent Culture  feed_time
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_    59.9800
# 1   DDB_PD_117_AMBR_HMP3071-003_R12_Main_    59.9800
# 2   DDB_PD_117_AMBR_HMP3071-003_R13_Main_    59.9775
# 3   DDB_PD_117_AMBR_HMP3071-003_R14_Main_    60.1775
# 4   DDB_PD_117_AMBR_HMP3071-003_R15_Main_    60.0400
# 5   DDB_PD_117_AMBR_HMP3071-003_R16_Main_    59.9750
# 6   DDB_PD_126_AMBR_HMP3071-003_R05_Main_    60.6100
# 7   DDB_PD_126_AMBR_HMP3071-003_R06_Main_    60.6075
# 8   DDB_PD_126_AMBR_HMP3071-003_R07_Main_    60.6175
# 9   DDB_PD_126_AMBR_HMP3071-003_R08_Main_    60.6300
# 10  DDB_PD_126_AMBR_HMP3071-003_R09_Main_    60.6300
# 11  DDB_PD_126_AMBR_HMP3071-003_R10_Main_    60.6275
# 12   DDB_PD_126_AMBR_SDT714-001_R11_Main_    60.6250
# 13   DDB_PD_126_AMBR_SDT714-001_R12_Main_    60.6250
# 14   DDB_PD_126_AMBR_SDT714-001_R13_Main_    60.6325
# 15   DDB_PD_126_AMBR_SDT714-001_R14_Main_    60.6650
# 16   DDB_PD_126_AMBR_SDT714-001_R15_Main_    60.6650
# 17   DDB_PD_126_AMBR_SDT714-001_R16_Main_    60.6750

# %% [markdown]
# As you can see above, the cultures and at different times now, which will make it hard to plot averages acrross strain and condition combination.

# %%
feed_end_df['feed_time_adjustment_for_equal_feed_volume'] = feed_end_df['feed_time'] - feed_end_df['feed_time'].max()
feed_end_adjustment = feed_end_df[['Parent Culture','feed_time_adjustment_for_equal_feed_volume']]
feed_end_adjustment
# Out:
#                            Parent Culture  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_
# 1   DDB_PD_117_AMBR_HMP3071-003_R12_Main_
# 2   DDB_PD_117_AMBR_HMP3071-003_R13_Main_
# 3   DDB_PD_117_AMBR_HMP3071-003_R14_Main_
# 4   DDB_PD_117_AMBR_HMP3071-003_R15_Main_
# 5   DDB_PD_117_AMBR_HMP3071-003_R16_Main_
# 6   DDB_PD_126_AMBR_HMP3071-003_R05_Main_
# 7   DDB_PD_126_AMBR_HMP3071-003_R06_Main_
# 8   DDB_PD_126_AMBR_HMP3071-003_R07_Main_
# 9   DDB_PD_126_AMBR_HMP3071-003_R08_Main_
# 10  DDB_PD_126_AMBR_HMP3071-003_R09_Main_
# 11  DDB_PD_126_AMBR_HMP3071-003_R10_Main_
# 12   DDB_PD_126_AMBR_SDT714-001_R11_Main_
# 13   DDB_PD_126_AMBR_SDT714-001_R12_Main_
# 14   DDB_PD_126_AMBR_SDT714-001_R13_Main_
# 15   DDB_PD_126_AMBR_SDT714-001_R14_Main_
# 16   DDB_PD_126_AMBR_SDT714-001_R15_Main_
# 17   DDB_PD_126_AMBR_SDT714-001_R16_Main_
#
#     feed_time_adjustment_for_equal_feed_volume
# 0                                      -0.6950
# 1                                      -0.6950
# 2                                      -0.6975
# 3                                      -0.4975
# 4                                      -0.6350
# 5                                      -0.7000
# 6                                      -0.0650
# 7                                      -0.0675
# 8                                      -0.0575
# 9                                      -0.0450
# 10                                     -0.0450
# 11                                     -0.0475
# 12                                     -0.0500
# 13                                     -0.0500
# 14                                     -0.0425
# 15                                     -0.0100
# 16                                     -0.0100
# 17                                      0.0000

# %%
# merge this adjustment values into online data
online_df = pd.merge(left=online_df,right=feed_end_adjustment,how='left')
# # adjusting feed time
online_df['adjusted_feed_time'] = np.round(online_df['feed_time'] - online_df['feed_time_adjustment_for_equal_feed_volume'],4)

# %% [markdown]
# ### Mol and Cmol conversions

# %% [markdown]
# #### Functions

# %%
def mass_to_mol(new_mol_col,mass_col,compound_mol_mass):
    offline_df[new_mol_col] = offline_df[mass_col]/compound_mol_mass

def mol_to_cmol(new_cmol_col,mol_col,n_c):
    offline_df[new_cmol_col] = offline_df[mol_col]*n_c

# %% [markdown]
# #### Biomass

# %%
new_mol_col = 'CDW_avg_molar'
mass_col = 'CDW_avg [g/L]'
compound_mol_mass = 24.6
new_cmol_col = 'CDW_avg_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Glucose

# %%
new_mol_col = 'glucose_molar'
mass_col = 'D-glucose [g/L]'
compound_mol_mass = 180.156
new_cmol_col = 'glucose_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Tryptophan

# %%
new_mol_col = 'tryptophan_molar'
mass_col = 'tryptophan [g/L]'
compound_mol_mass = 204.23
new_cmol_col = 'tryptophan_cmolar'
mol_col = new_mol_col
n_c = 11

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Acetate

# %%
new_mol_col = 'acetic_acid_molar'
mass_col = 'acetic acid [g/L]'
compound_mol_mass = 60.052 
new_cmol_col = 'acetic_acid_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Citrate

# %%
new_mol_col = 'citric_acid_molar'
mass_col = 'citric acid [g/L]'
compound_mol_mass = 192.124
new_cmol_col = 'citric_acid_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Ethanol

# %%
new_mol_col = 'ethanol_molar'
mass_col = 'ethanol [g/L]'
compound_mol_mass = 46.07
new_cmol_col = 'ethanol_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Formate

# %%
new_mol_col = 'formic_acid_molar'
mass_col = 'formic acid [g/L]'
compound_mol_mass = 46.03
new_cmol_col = 'formic_acid_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Lactate

# %%
new_mol_col = 'lactate_molar'
mass_col = 'lactate [g/L]'
compound_mol_mass = 90.08
new_cmol_col = 'lactate_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Pyruvate

# %%
new_mol_col = 'pyruvic_acid_molar'
mass_col = 'pyruvic acid [g/L]'
compound_mol_mass = 88.06
new_cmol_col = 'pyruvic_acid_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Succinate

# %%
new_mol_col = 'succinic_acid_molar'
mass_col = 'succinic acid [g/L]'
compound_mol_mass = 118.09
new_cmol_col = 'succinic_acid_cmolar'
mol_col = new_mol_col
n_c = 4

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %%
offline_df
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  ethanol_molar  ethanol_cmolar  formic_acid_molar  \
# 0            0.426389  ...       0.002469        0.004939           0.005182
# 1            0.000000  ...       0.000000        0.000000           0.000000
# 2            0.000000  ...       0.000000        0.000000           0.000000
# 3            0.354635  ...       0.000000        0.000000           0.004617
# 4            0.910389  ...       0.000000        0.000000           0.013231
# ..                ...  ...            ...             ...                ...
# 85           0.321480  ...       0.000000        0.000000           0.000000
# 86           0.080446  ...       0.000000        0.000000           0.000000
# 87           0.062385  ...       0.000000        0.000000           0.000000
# 88           0.460868  ...       0.000000        0.000000           0.006015
# 89           1.054493  ...       0.000000        0.000000           0.019510
#
#     formic_acid_cmolar  lactate_molar  lactate_cmolar  pyruvic_acid_molar  \
# 0             0.005182       0.000000        0.000000            0.002399
# 1             0.000000       0.000000        0.000000            0.000000
# 2             0.000000       0.000000        0.000000            0.000000
# 3             0.004617       0.000000        0.000000            0.000000
# 4             0.013231       0.001909        0.005727            0.000000
# ..                 ...            ...             ...                 ...
# 85            0.000000       0.000000        0.000000            0.002485
# 86            0.000000       0.000000        0.000000            0.000000
# 87            0.000000       0.000363        0.001088            0.000000
# 88            0.006015       0.000475        0.001425            0.000000
# 89            0.019510       0.001290        0.003870            0.000707
#
#     pyruvic_acid_cmolar  succinic_acid_molar  succinic_acid_cmolar
# 0              0.007197             0.000000              0.000000
# 1              0.000000             0.000000              0.000000
# 2              0.000000             0.000000              0.000000
# 3              0.000000             0.000000              0.000000
# 4              0.000000             0.003821              0.015283
# ..                  ...                  ...                   ...
# 85             0.007456             0.000000              0.000000
# 86             0.000000             0.000000              0.000000
# 87             0.000000             0.000000              0.000000
# 88             0.000000             0.001148              0.004592
# 89             0.002122             0.002652              0.010609
#
# [90 rows x 50 columns]

# %% [markdown]
# ### Advanced calculations

# %% [markdown]
# #### Functions

# %%
def lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col):
    offline_df[new_lost_col] = offline_df[measurement_col] * offline_df['Sample volume (mL)']/1000
    offline_df[new_lost_cumsum_col] = offline_df.groupby(['Parent Culture']).cumsum()[new_lost_col]
    offline_df[new_lost_cumsum_col] = offline_df.groupby('Parent Culture').shift()[new_lost_cumsum_col].fillna(0)
    
def net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = offline_df[residual_col]*offline_df['Liquid_volume']/1000 + offline_df[lost_cumsum_col] - init_amount - feed_conc*offline_df['Feed_volume']/1000
    
def net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = -offline_df[residual_col]*offline_df['Liquid_volume']/1000 - offline_df[lost_cumsum_col] + init_amount + feed_conc*offline_df['Feed_volume']/1000

# %% [markdown]
# #### Lost masses (due to sampling) calculations

# %% [markdown]
# ##### Lost biomass (cmol)

# %%
new_lost_col = 'lost_biomass_cmol'
new_lost_cumsum_col = 'lost_biomass_cumsum_cmol'
measurement_col = 'CDW_avg_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost biomass (g)

# %%
new_lost_col = 'lost_biomass_g'
new_lost_cumsum_col = 'lost_biomass_cumsum_g'
measurement_col = 'CDW_avg [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (cmol)

# %%
new_lost_col = 'lost_glucose_cmol'
new_lost_cumsum_col = 'lost_glucose_cumsum_cmol'
measurement_col = 'glucose_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (g)

# %%
new_lost_col = 'lost_glucose_g'
new_lost_cumsum_col = 'lost_glucose_cumsum_g'
measurement_col = 'D-glucose [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost tryptophan (cmol)

# %%
new_lost_col = 'lost_tryptophan_cmol'
new_lost_cumsum_col = 'lost_tryptophan_cumsum_cmol'
measurement_col = 'tryptophan_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost acetate (cmol)

# %%
new_lost_col = 'lost_acetic_acid_cmol'
new_lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
measurement_col = 'acetic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost citrate (cmol)

# %%
new_lost_col = 'lost_citric_acid_cmol'
new_lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
measurement_col = 'citric_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost ethanol (cmol)

# %%
new_lost_col = 'lost_ethanol_cmol'
new_lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
measurement_col = 'ethanol_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost formate (cmol)

# %%
new_lost_col = 'lost_formic_acid_cmol'
new_lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
measurement_col = 'formic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost lactate (cmol)

# %%
new_lost_col = 'lost_lactate_cmol'
new_lost_cumsum_col = 'lost_lactate_cumsum_cmol'
measurement_col = 'lactate_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost pyruvate (cmol)

# %%
new_lost_col = 'lost_pyruvic_acid_cmol'
new_lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
measurement_col = 'pyruvic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost succinate (cmol)

# %%
new_lost_col = 'lost_succinic_acid_cmol'
new_lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
measurement_col = 'succinic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %%
offline_df
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  lost_ethanol_cmol  lost_ethanol_cumsum_cmol  \
# 0            0.426389  ...           0.000035                  0.000000
# 1            0.000000  ...           0.000000                  0.000035
# 2            0.000000  ...           0.000000                  0.000035
# 3            0.354635  ...           0.000000                  0.000035
# 4            0.910389  ...           0.000000                  0.000035
# ..                ...  ...                ...                       ...
# 85           0.321480  ...           0.000000                  0.000000
# 86           0.080446  ...           0.000000                  0.000000
# 87           0.062385  ...           0.000000                  0.000000
# 88           0.460868  ...           0.000000                  0.000000
# 89           1.054493  ...           0.000000                  0.000000
#
#     lost_formic_acid_cmol  lost_formic_acid_cumsum_cmol  lost_lactate_cmol  \
# 0                0.000036                      0.000000           0.000000
# 1                0.000000                      0.000036           0.000000
# 2                0.000000                      0.000036           0.000000
# 3                0.000016                      0.000036           0.000000
# 4                0.000099                      0.000052           0.000043
# ..                    ...                           ...                ...
# 85               0.000000                      0.000000           0.000000
# 86               0.000000                      0.000000           0.000000
# 87               0.000000                      0.000000           0.000006
# 88               0.000033                      0.000000           0.000008
# 89               0.000146                      0.000033           0.000029
#
#     lost_lactate_cumsum_cmol  lost_pyruvic_acid_cmol  \
# 0                   0.000000                0.000050
# 1                   0.000000                0.000000
# 2                   0.000000                0.000000
# 3                   0.000000                0.000000
# 4                   0.000000                0.000000
# ..                       ...                     ...
# 85                  0.000000                0.000052
# 86                  0.000000                0.000000
# 87                  0.000000                0.000000
# 88                  0.000006                0.000000
# 89                  0.000014                0.000016
#
#     lost_pyruvic_acid_cumsum_cmol  lost_succinic_acid_cmol  \
# 0                        0.000000                 0.000000
# 1                        0.000050                 0.000000
# 2                        0.000050                 0.000000
# 3                        0.000050                 0.000000
# 4                        0.000050                 0.000115
# ..                            ...                      ...
# 85                       0.000000                 0.000000
# 86                       0.000052                 0.000000
# 87                       0.000052                 0.000000
# 88                       0.000052                 0.000025
# 89                       0.000052                 0.000080
#
#     lost_succinic_acid_cumsum_cmol
# 0                         0.000000
# 1                         0.000000
# 2                         0.000000
# 3                         0.000000
# 4                         0.000000
# ..                             ...
# 85                        0.000000
# 86                        0.000000
# 87                        0.000000
# 88                        0.000000
# 89                        0.000025
#
# [90 rows x 74 columns]

# %% [markdown]
# #### Liquid and feeding volume from online data into offline data

# %%
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
slice_offline_df
# Out:
#                            Parent Culture       Time Timepoint (#)
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  12.276657           S01
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  16.779256           S02
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  36.846045           S03
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  56.969901           S04
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  77.008533           S05
# ..                                    ...        ...           ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_  12.566374           S01
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_  20.938572           S02
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_  40.981357           S03
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_  60.981844           S04
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_  80.980182           S05
#
# [90 rows x 3 columns]

# %%
online_df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0        0.0000  98.980448  6.540237     999.842286    29.999211  3.295611
# 1        0.0025  98.204786  6.542484     998.344073    29.991720  4.992337
# 2        0.0050  97.399798  6.544142     999.141427    29.978585  5.437930
# 3        0.0075  96.793518  6.545943    1001.257502    29.969999  5.459251
# 4        0.0100  96.488269  6.547690    1003.565767    29.969379  5.405501
# ...         ...        ...       ...            ...          ...       ...
# 569653  81.6625  -0.225624  6.447796     500.068040    29.935918  1.296619
# 569654  81.6650  -0.243608  6.445576     500.808036    29.891517  1.270719
# 569655  81.6675  -0.251021  6.443884     499.325514    29.840928  1.280745
# 569656  81.6700  -0.254470  6.442383     498.925096    29.788414  1.309418
# 569657  81.6725  -0.257820  6.440824     500.824483    29.734734  1.336979
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  Phase  \
# 0        99.963918     0.000000         20.95  20.696315  ...  batch
# 1        99.963169     0.000000         20.95  20.699312  ...  batch
# 2       100.094834     0.000000         20.95  20.700571  ...  batch
# 3       100.074538     0.000000         20.95  20.698800  ...  batch
# 4        99.829263     0.000000         20.95  20.693752  ...  batch
# ...            ...          ...           ...        ...  ...    ...
# 569653    0.000000     9.955355        100.00  16.039389  ...   feed
# 569654    0.000000    10.002715        100.00  16.032728  ...   feed
# 569655    0.000000    10.008860        100.00  16.024302  ...   feed
# 569656    0.000000    10.016026        100.00  16.014374  ...   feed
# 569657    0.000000    10.041772        100.00  16.003385  ...   feed
#
#         DO Control Setpoint (%)  DO Control Cascade Level 1  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 569653                     40.0                    Stirring
# 569654                     40.0                    Stirring
# 569655                     40.0                    Stirring
# 569656                     40.0                    Stirring
# 569657                     40.0                    Stirring
#
#         DO Control Cascade Level 2  DO Control Cascade Level 3   Condition  \
# 0                              NaN                         NaN     control
# 1                              NaN                         NaN     control
# 2                              NaN                         NaN     control
# 3                              NaN                         NaN     control
# 4                              NaN                         NaN     control
# ...                            ...                         ...         ...
# 569653                    Aeration                      Oxygen  scale-down
# 569654                    Aeration                      Oxygen  scale-down
# 569655                    Aeration                      Oxygen  scale-down
# 569656                    Aeration                      Oxygen  scale-down
# 569657                    Aeration                      Oxygen  scale-down
#
#         batch_end  feed_time  feed_time_adjustment_for_equal_feed_volume  \
# 0         16.8600   -16.8600                                      -0.695
# 1         16.8600   -16.8575                                      -0.695
# 2         16.8600   -16.8550                                      -0.695
# 3         16.8600   -16.8525                                      -0.695
# 4         16.8600   -16.8500                                      -0.695
# ...           ...        ...                                         ...
# 569653    20.9975    60.6650                                       0.000
# 569654    20.9975    60.6675                                       0.000
# 569655    20.9975    60.6700                                       0.000
# 569656    20.9975    60.6725                                       0.000
# 569657    20.9975    60.6750                                       0.000
#
#         adjusted_feed_time
# 0                 -16.1650
# 1                 -16.1625
# 2                 -16.1600
# 3                 -16.1575
# 4                 -16.1550
# ...                    ...
# 569653             60.6650
# 569654             60.6675
# 569655             60.6700
# 569656             60.6725
# 569657             60.6750
#
# [569658 rows x 57 columns]

# %%
df = pd.concat([online_df,slice_offline_df])
df
# Out:
#          Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0    0.000000  98.980448  6.540237     999.842286    29.999211  3.295611
# 1    0.002500  98.204786  6.542484     998.344073    29.991720  4.992337
# 2    0.005000  97.399798  6.544142     999.141427    29.978585  5.437930
# 3    0.007500  96.793518  6.545943    1001.257502    29.969999  5.459251
# 4    0.010000  96.488269  6.547690    1003.565767    29.969379  5.405501
# ..        ...        ...       ...            ...          ...       ...
# 85  12.566374        NaN       NaN            NaN          NaN       NaN
# 86  20.938572        NaN       NaN            NaN          NaN       NaN
# 87  40.981357        NaN       NaN            NaN          NaN       NaN
# 88  60.981844        NaN       NaN            NaN          NaN       NaN
# 89  80.980182        NaN       NaN            NaN          NaN       NaN
#
#       Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0    99.963918          0.0         20.95  20.696315  ...
# 1    99.963169          0.0         20.95  20.699312  ...
# 2   100.094834          0.0         20.95  20.700571  ...
# 3   100.074538          0.0         20.95  20.698800  ...
# 4    99.829263          0.0         20.95  20.693752  ...
# ..         ...          ...           ...        ...  ...
# 85         NaN          NaN           NaN        NaN  ...
# 86         NaN          NaN           NaN        NaN  ...
# 87         NaN          NaN           NaN        NaN  ...
# 88         NaN          NaN           NaN        NaN  ...
# 89         NaN          NaN           NaN        NaN  ...
#
#     DO Control Setpoint (%)  DO Control Cascade Level 1  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ..                      ...                         ...
# 85                      NaN                         NaN
# 86                      NaN                         NaN
# 87                      NaN                         NaN
# 88                      NaN                         NaN
# 89                      NaN                         NaN
#
#     DO Control Cascade Level 2  DO Control Cascade Level 3  Condition  \
# 0                          NaN                         NaN    control
# 1                          NaN                         NaN    control
# 2                          NaN                         NaN    control
# 3                          NaN                         NaN    control
# 4                          NaN                         NaN    control
# ..                         ...                         ...        ...
# 85                         NaN                         NaN        NaN
# 86                         NaN                         NaN        NaN
# 87                         NaN                         NaN        NaN
# 88                         NaN                         NaN        NaN
# 89                         NaN                         NaN        NaN
#
#     batch_end  feed_time  feed_time_adjustment_for_equal_feed_volume  \
# 0       16.86   -16.8600                                      -0.695
# 1       16.86   -16.8575                                      -0.695
# 2       16.86   -16.8550                                      -0.695
# 3       16.86   -16.8525                                      -0.695
# 4       16.86   -16.8500                                      -0.695
# ..        ...        ...                                         ...
# 85        NaN        NaN                                         NaN
# 86        NaN        NaN                                         NaN
# 87        NaN        NaN                                         NaN
# 88        NaN        NaN                                         NaN
# 89        NaN        NaN                                         NaN
#
#     adjusted_feed_time  Timepoint (#)
# 0             -16.1650            NaN
# 1             -16.1625            NaN
# 2             -16.1600            NaN
# 3             -16.1575            NaN
# 4             -16.1550            NaN
# ..                 ...            ...
# 85                 NaN            S01
# 86                 NaN            S02
# 87                 NaN            S03
# 88                 NaN            S04
# 89                 NaN            S05
#
# [569748 rows x 58 columns]

# %%
df.sort_values(['Parent Culture','Time'],inplace=True)
df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0        0.0000  98.980448  6.540237     999.842286    29.999211  3.295611
# 1        0.0025  98.204786  6.542484     998.344073    29.991720  4.992337
# 2        0.0050  97.399798  6.544142     999.141427    29.978585  5.437930
# 3        0.0075  96.793518  6.545943    1001.257502    29.969999  5.459251
# 4        0.0100  96.488269  6.547690    1003.565767    29.969379  5.405501
# ...         ...        ...       ...            ...          ...       ...
# 569653  81.6625  -0.225624  6.447796     500.068040    29.935918  1.296619
# 569654  81.6650  -0.243608  6.445576     500.808036    29.891517  1.270719
# 569655  81.6675  -0.251021  6.443884     499.325514    29.840928  1.280745
# 569656  81.6700  -0.254470  6.442383     498.925096    29.788414  1.309418
# 569657  81.6725  -0.257820  6.440824     500.824483    29.734734  1.336979
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0        99.963918     0.000000         20.95  20.696315  ...
# 1        99.963169     0.000000         20.95  20.699312  ...
# 2       100.094834     0.000000         20.95  20.700571  ...
# 3       100.074538     0.000000         20.95  20.698800  ...
# 4        99.829263     0.000000         20.95  20.693752  ...
# ...            ...          ...           ...        ...  ...
# 569653    0.000000     9.955355        100.00  16.039389  ...
# 569654    0.000000    10.002715        100.00  16.032728  ...
# 569655    0.000000    10.008860        100.00  16.024302  ...
# 569656    0.000000    10.016026        100.00  16.014374  ...
# 569657    0.000000    10.041772        100.00  16.003385  ...
#
#         DO Control Setpoint (%)  DO Control Cascade Level 1  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 569653                     40.0                    Stirring
# 569654                     40.0                    Stirring
# 569655                     40.0                    Stirring
# 569656                     40.0                    Stirring
# 569657                     40.0                    Stirring
#
#         DO Control Cascade Level 2  DO Control Cascade Level 3   Condition  \
# 0                              NaN                         NaN     control
# 1                              NaN                         NaN     control
# 2                              NaN                         NaN     control
# 3                              NaN                         NaN     control
# 4                              NaN                         NaN     control
# ...                            ...                         ...         ...
# 569653                    Aeration                      Oxygen  scale-down
# 569654                    Aeration                      Oxygen  scale-down
# 569655                    Aeration                      Oxygen  scale-down
# 569656                    Aeration                      Oxygen  scale-down
# 569657                    Aeration                      Oxygen  scale-down
#
#         batch_end  feed_time  feed_time_adjustment_for_equal_feed_volume  \
# 0         16.8600   -16.8600                                      -0.695
# 1         16.8600   -16.8575                                      -0.695
# 2         16.8600   -16.8550                                      -0.695
# 3         16.8600   -16.8525                                      -0.695
# 4         16.8600   -16.8500                                      -0.695
# ...           ...        ...                                         ...
# 569653    20.9975    60.6650                                       0.000
# 569654    20.9975    60.6675                                       0.000
# 569655    20.9975    60.6700                                       0.000
# 569656    20.9975    60.6725                                       0.000
# 569657    20.9975    60.6750                                       0.000
#
#         adjusted_feed_time  Timepoint (#)
# 0                 -16.1650            NaN
# 1                 -16.1625            NaN
# 2                 -16.1600            NaN
# 3                 -16.1575            NaN
# 4                 -16.1550            NaN
# ...                    ...            ...
# 569653             60.6650            NaN
# 569654             60.6675            NaN
# 569655             60.6700            NaN
# 569656             60.6725            NaN
# 569657             60.6750            NaN
#
# [569748 rows x 58 columns]

# %%
df['Liquid_volume'] = df['Liquid_volume'].fillna(method='ffill')
df['Feed_volume'] = df['Feed_volume'].fillna(method='ffill')
df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0        0.0000  98.980448  6.540237     999.842286    29.999211  3.295611
# 1        0.0025  98.204786  6.542484     998.344073    29.991720  4.992337
# 2        0.0050  97.399798  6.544142     999.141427    29.978585  5.437930
# 3        0.0075  96.793518  6.545943    1001.257502    29.969999  5.459251
# 4        0.0100  96.488269  6.547690    1003.565767    29.969379  5.405501
# ...         ...        ...       ...            ...          ...       ...
# 569653  81.6625  -0.225624  6.447796     500.068040    29.935918  1.296619
# 569654  81.6650  -0.243608  6.445576     500.808036    29.891517  1.270719
# 569655  81.6675  -0.251021  6.443884     499.325514    29.840928  1.280745
# 569656  81.6700  -0.254470  6.442383     498.925096    29.788414  1.309418
# 569657  81.6725  -0.257820  6.440824     500.824483    29.734734  1.336979
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0        99.963918     0.000000         20.95  20.696315  ...
# 1        99.963169     0.000000         20.95  20.699312  ...
# 2       100.094834     0.000000         20.95  20.700571  ...
# 3       100.074538     0.000000         20.95  20.698800  ...
# 4        99.829263     0.000000         20.95  20.693752  ...
# ...            ...          ...           ...        ...  ...
# 569653    0.000000     9.955355        100.00  16.039389  ...
# 569654    0.000000    10.002715        100.00  16.032728  ...
# 569655    0.000000    10.008860        100.00  16.024302  ...
# 569656    0.000000    10.016026        100.00  16.014374  ...
# 569657    0.000000    10.041772        100.00  16.003385  ...
#
#         DO Control Setpoint (%)  DO Control Cascade Level 1  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 569653                     40.0                    Stirring
# 569654                     40.0                    Stirring
# 569655                     40.0                    Stirring
# 569656                     40.0                    Stirring
# 569657                     40.0                    Stirring
#
#         DO Control Cascade Level 2  DO Control Cascade Level 3   Condition  \
# 0                              NaN                         NaN     control
# 1                              NaN                         NaN     control
# 2                              NaN                         NaN     control
# 3                              NaN                         NaN     control
# 4                              NaN                         NaN     control
# ...                            ...                         ...         ...
# 569653                    Aeration                      Oxygen  scale-down
# 569654                    Aeration                      Oxygen  scale-down
# 569655                    Aeration                      Oxygen  scale-down
# 569656                    Aeration                      Oxygen  scale-down
# 569657                    Aeration                      Oxygen  scale-down
#
#         batch_end  feed_time  feed_time_adjustment_for_equal_feed_volume  \
# 0         16.8600   -16.8600                                      -0.695
# 1         16.8600   -16.8575                                      -0.695
# 2         16.8600   -16.8550                                      -0.695
# 3         16.8600   -16.8525                                      -0.695
# 4         16.8600   -16.8500                                      -0.695
# ...           ...        ...                                         ...
# 569653    20.9975    60.6650                                       0.000
# 569654    20.9975    60.6675                                       0.000
# 569655    20.9975    60.6700                                       0.000
# 569656    20.9975    60.6725                                       0.000
# 569657    20.9975    60.6750                                       0.000
#
#         adjusted_feed_time  Timepoint (#)
# 0                 -16.1650            NaN
# 1                 -16.1625            NaN
# 2                 -16.1600            NaN
# 3                 -16.1575            NaN
# 4                 -16.1550            NaN
# ...                    ...            ...
# 569653             60.6650            NaN
# 569654             60.6675            NaN
# 569655             60.6700            NaN
# 569656             60.6725            NaN
# 569657             60.6750            NaN
#
# [569748 rows x 58 columns]

# %%
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
df
# Out:
#          Time  DO  pH  Stirrer_speed  Temperature  Pressure  Air_flow  \
# 0   12.276657 NaN NaN            NaN          NaN       NaN       NaN
# 1   16.779256 NaN NaN            NaN          NaN       NaN       NaN
# 2   36.846045 NaN NaN            NaN          NaN       NaN       NaN
# 3   56.969901 NaN NaN            NaN          NaN       NaN       NaN
# 4   77.008533 NaN NaN            NaN          NaN       NaN       NaN
# ..        ...  ..  ..            ...          ...       ...       ...
# 85  12.566374 NaN NaN            NaN          NaN       NaN       NaN
# 86  20.938572 NaN NaN            NaN          NaN       NaN       NaN
# 87  40.981357 NaN NaN            NaN          NaN       NaN       NaN
# 88  60.981844 NaN NaN            NaN          NaN       NaN       NaN
# 89  80.980182 NaN NaN            NaN          NaN       NaN       NaN
#
#     Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  DO Control Setpoint (%)  \
# 0           NaN           NaN        NaN  ...                      NaN
# 1           NaN           NaN        NaN  ...                      NaN
# 2           NaN           NaN        NaN  ...                      NaN
# 3           NaN           NaN        NaN  ...                      NaN
# 4           NaN           NaN        NaN  ...                      NaN
# ..          ...           ...        ...  ...                      ...
# 85          NaN           NaN        NaN  ...                      NaN
# 86          NaN           NaN        NaN  ...                      NaN
# 87          NaN           NaN        NaN  ...                      NaN
# 88          NaN           NaN        NaN  ...                      NaN
# 89          NaN           NaN        NaN  ...                      NaN
#
#     DO Control Cascade Level 1  DO Control Cascade Level 2  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 85                         NaN                         NaN
# 86                         NaN                         NaN
# 87                         NaN                         NaN
# 88                         NaN                         NaN
# 89                         NaN                         NaN
#
#     DO Control Cascade Level 3  Condition  batch_end  feed_time  \
# 0                          NaN        NaN        NaN        NaN
# 1                          NaN        NaN        NaN        NaN
# 2                          NaN        NaN        NaN        NaN
# 3                          NaN        NaN        NaN        NaN
# 4                          NaN        NaN        NaN        NaN
# ..                         ...        ...        ...        ...
# 85                         NaN        NaN        NaN        NaN
# 86                         NaN        NaN        NaN        NaN
# 87                         NaN        NaN        NaN        NaN
# 88                         NaN        NaN        NaN        NaN
# 89                         NaN        NaN        NaN        NaN
#
#     feed_time_adjustment_for_equal_feed_volume  adjusted_feed_time  \
# 0                                          NaN                 NaN
# 1                                          NaN                 NaN
# 2                                          NaN                 NaN
# 3                                          NaN                 NaN
# 4                                          NaN                 NaN
# ..                                         ...                 ...
# 85                                         NaN                 NaN
# 86                                         NaN                 NaN
# 87                                         NaN                 NaN
# 88                                         NaN                 NaN
# 89                                         NaN                 NaN
#
#     Timepoint (#)
# 0             S01
# 1             S02
# 2             S03
# 3             S04
# 4             S05
# ..            ...
# 85            S01
# 86            S02
# 87            S03
# 88            S04
# 89            S05
#
# [90 rows x 58 columns]

# %%
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Liquid_volume','Feed_volume']]
df
# Out:
#                            Parent Culture Timepoint (#)  Liquid_volume  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_           S01     101.668785
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_           S02      97.796310
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_           S03      98.424506
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_           S04     114.561104
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_           S05     163.683672
# ..                                    ...           ...            ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_           S01     100.031542
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_           S02      96.402929
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_           S03      97.263451
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_           S04     111.055801
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_           S05     155.886804
#
#     Feed_volume
# 0      0.000000
# 1      0.000000
# 2      6.045374
# 3     21.952049
# 4     63.047323
# ..          ...
# 85     0.000000
# 86     0.000000
# 87     6.019649
# 88    21.404734
# 89    61.066909
#
# [90 rows x 4 columns]

# %%
offline_df['Parent Culture'].unique()
# Out:
# array(['DDB_PD_117_AMBR_HMP3071-003_R11_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R12_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R13_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R14_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R15_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R16_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R05_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R06_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R07_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R08_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R09_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R10_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R11_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R12_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R13_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R14_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R15_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R16_Main_'], dtype=object)

# %%
df['Parent Culture'].unique()
# Out:
# array(['DDB_PD_117_AMBR_HMP3071-003_R11_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R12_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R13_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R14_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R15_Main_',
#        'DDB_PD_117_AMBR_HMP3071-003_R16_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R05_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R06_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R07_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R08_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R09_Main_',
#        'DDB_PD_126_AMBR_HMP3071-003_R10_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R11_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R12_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R13_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R14_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R15_Main_',
#        'DDB_PD_126_AMBR_SDT714-001_R16_Main_'], dtype=object)

# %%
pd.concat([offline_df,df[['Liquid_volume','Feed_volume']]],axis=1)
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  lost_formic_acid_cmol  \
# 0            0.426389  ...               0.000036
# 1            0.000000  ...               0.000000
# 2            0.000000  ...               0.000000
# 3            0.354635  ...               0.000016
# 4            0.910389  ...               0.000099
# ..                ...  ...                    ...
# 85           0.321480  ...               0.000000
# 86           0.080446  ...               0.000000
# 87           0.062385  ...               0.000000
# 88           0.460868  ...               0.000033
# 89           1.054493  ...               0.000146
#
#     lost_formic_acid_cumsum_cmol  lost_lactate_cmol  lost_lactate_cumsum_cmol  \
# 0                       0.000000           0.000000                  0.000000
# 1                       0.000036           0.000000                  0.000000
# 2                       0.000036           0.000000                  0.000000
# 3                       0.000036           0.000000                  0.000000
# 4                       0.000052           0.000043                  0.000000
# ..                           ...                ...                       ...
# 85                      0.000000           0.000000                  0.000000
# 86                      0.000000           0.000000                  0.000000
# 87                      0.000000           0.000006                  0.000000
# 88                      0.000000           0.000008                  0.000006
# 89                      0.000033           0.000029                  0.000014
#
#     lost_pyruvic_acid_cmol  lost_pyruvic_acid_cumsum_cmol  \
# 0                 0.000050                       0.000000
# 1                 0.000000                       0.000050
# 2                 0.000000                       0.000050
# 3                 0.000000                       0.000050
# 4                 0.000000                       0.000050
# ..                     ...                            ...
# 85                0.000052                       0.000000
# 86                0.000000                       0.000052
# 87                0.000000                       0.000052
# 88                0.000000                       0.000052
# 89                0.000016                       0.000052
#
#     lost_succinic_acid_cmol  lost_succinic_acid_cumsum_cmol  Liquid_volume  \
# 0                  0.000000                        0.000000     101.668785
# 1                  0.000000                        0.000000      97.796310
# 2                  0.000000                        0.000000      98.424506
# 3                  0.000000                        0.000000     114.561104
# 4                  0.000115                        0.000000     163.683672
# ..                      ...                             ...            ...
# 85                 0.000000                        0.000000     100.031542
# 86                 0.000000                        0.000000      96.402929
# 87                 0.000000                        0.000000      97.263451
# 88                 0.000025                        0.000000     111.055801
# 89                 0.000080                        0.000025     155.886804
#
#     Feed_volume
# 0      0.000000
# 1      0.000000
# 2      6.045374
# 3     21.952049
# 4     63.047323
# ..          ...
# 85     0.000000
# 86     0.000000
# 87     6.019649
# 88    21.404734
# 89    61.066909
#
# [90 rows x 76 columns]

# %%
pd.merge(left=offline_df,right=df,how='inner')
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  lost_formic_acid_cmol  \
# 0            0.426389  ...               0.000036
# 1            0.000000  ...               0.000000
# 2            0.000000  ...               0.000000
# 3            0.354635  ...               0.000016
# 4            0.910389  ...               0.000099
# ..                ...  ...                    ...
# 85           0.321480  ...               0.000000
# 86           0.080446  ...               0.000000
# 87           0.062385  ...               0.000000
# 88           0.460868  ...               0.000033
# 89           1.054493  ...               0.000146
#
#     lost_formic_acid_cumsum_cmol  lost_lactate_cmol  lost_lactate_cumsum_cmol  \
# 0                       0.000000           0.000000                  0.000000
# 1                       0.000036           0.000000                  0.000000
# 2                       0.000036           0.000000                  0.000000
# 3                       0.000036           0.000000                  0.000000
# 4                       0.000052           0.000043                  0.000000
# ..                           ...                ...                       ...
# 85                      0.000000           0.000000                  0.000000
# 86                      0.000000           0.000000                  0.000000
# 87                      0.000000           0.000006                  0.000000
# 88                      0.000000           0.000008                  0.000006
# 89                      0.000033           0.000029                  0.000014
#
#     lost_pyruvic_acid_cmol  lost_pyruvic_acid_cumsum_cmol  \
# 0                 0.000050                       0.000000
# 1                 0.000000                       0.000050
# 2                 0.000000                       0.000050
# 3                 0.000000                       0.000050
# 4                 0.000000                       0.000050
# ..                     ...                            ...
# 85                0.000052                       0.000000
# 86                0.000000                       0.000052
# 87                0.000000                       0.000052
# 88                0.000000                       0.000052
# 89                0.000016                       0.000052
#
#     lost_succinic_acid_cmol  lost_succinic_acid_cumsum_cmol  Liquid_volume  \
# 0                  0.000000                        0.000000     101.668785
# 1                  0.000000                        0.000000      97.796310
# 2                  0.000000                        0.000000      98.424506
# 3                  0.000000                        0.000000     114.561104
# 4                  0.000115                        0.000000     163.683672
# ..                      ...                             ...            ...
# 85                 0.000000                        0.000000     100.031542
# 86                 0.000000                        0.000000      96.402929
# 87                 0.000000                        0.000000      97.263451
# 88                 0.000025                        0.000000     111.055801
# 89                 0.000080                        0.000025     155.886804
#
#     Feed_volume
# 0      0.000000
# 1      0.000000
# 2      6.045374
# 3     21.952049
# 4     63.047323
# ..          ...
# 85     0.000000
# 86     0.000000
# 87     6.019649
# 88    21.404734
# 89    61.066909
#
# [90 rows x 76 columns]

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
# concat online with sliced dataframe
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values in liquid volume column from offline data rows with the previous liquid volume value from the online data 
df['Liquid_volume'] = df['Liquid_volume'].fillna(method='ffill')
df['Feed_volume'] = df['Feed_volume'].fillna(method='ffill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Liquid_volume','Feed_volume']]
offline_df = pd.concat([offline_df,df[['Liquid_volume','Feed_volume']]],axis=1)

# %%
offline_df.to_excel("offline_df_after_online_volume_addition.xlsx")

# %% [markdown]
# #### Net compound formation/consumption

# %% [markdown]
# ##### Net biomass (cmol)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_cmol'
residual_col = 'CDW_avg_cmolar'
new_net_col = 'net_biomass_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net biomass (g)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_g'
residual_col = 'CDW_avg [g/L]'
new_net_col = 'net_biomass_g'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (cmol)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_cmol'
residual_col = 'glucose_cmolar'
new_net_col = 'net_glucose_cmol'
feed_conc = 500/180.156*6
init_amount = 2/180.156*6

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (g)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_g'
residual_col = 'D-glucose [g/L]'
new_net_col = 'net_glucose_g'
feed_conc = 500
init_amount = 2

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net tryptophan (cmol)

# %%
lost_cumsum_col = 'lost_tryptophan_cumsum_cmol'
residual_col = 'tryptophan_cmolar'
new_net_col = 'net_tryptophan_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net acetate (cmol)

# %%
lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
residual_col = 'acetic_acid_cmolar'
new_net_col = 'net_acetic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net citrate (cmol)

# %%
lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
residual_col = 'citric_acid_cmolar'
new_net_col = 'net_citric_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net ethanol (cmol)

# %%
lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
residual_col = 'ethanol_cmolar'
new_net_col = 'net_ethanol_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net formate (cmol)

# %%
lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
residual_col = 'formic_acid_cmolar'
new_net_col = 'net_formic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net lactate (cmol)

# %%
lost_cumsum_col = 'lost_lactate_cumsum_cmol'
residual_col = 'lactate_cmolar'
new_net_col = 'net_lactate_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net pyruvate (cmol)

# %%
lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
residual_col = 'pyruvic_acid_cmolar'
new_net_col = 'net_pyruvic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net succinate (cmol)

# %%
lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
residual_col = 'succinic_acid_cmolar'
new_net_col = 'net_succinic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %%
offline_df
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  net_glucose_cmol  net_glucose_g  \
# 0            0.426389  ...          0.020226       0.607321
# 1            0.000000  ...          0.063415       1.904113
# 2            0.000000  ...          0.164084       4.926800
# 3            0.354635  ...          0.428966      12.880137
# 4            0.910389  ...          1.113294      33.427774
# ..                ...  ...               ...            ...
# 85           0.321480  ...          0.017295       0.519306
# 86           0.080446  ...          0.063158       1.896384
# 87           0.062385  ...          0.163399       4.906208
# 88           0.460868  ...          0.419595      12.598751
# 89           1.054493  ...          1.080059      32.429838
#
#     net_tryptophan_cmol  net_acetic_acid_cmol  net_citric_acid_cmol  \
# 0              0.000787              0.001444              0.001397
# 1              0.003869              0.000099              0.001514
# 2              0.007768              0.000099              0.001818
# 3              0.012472              0.001452              0.002332
# 4              0.026008              0.005104              0.005597
# ..                  ...                   ...                   ...
# 85             0.000000              0.001071              0.000628
# 86             0.001368              0.000333              0.000636
# 87             0.005437              0.000290              0.000968
# 88             0.008427              0.001804              0.001473
# 89             0.013944              0.005659              0.002839
#
#     net_ethanol_cmol  net_formic_acid_cmol  net_lactate_cmol  \
# 0           0.000502              0.000527          0.000000
# 1           0.000035              0.000036          0.000000
# 2           0.000035              0.000036          0.000000
# 3           0.000035              0.000565          0.000000
# 4           0.000035              0.002218          0.000937
# ..               ...                   ...               ...
# 85          0.000000              0.000000          0.000000
# 86          0.000000              0.000000          0.000000
# 87          0.000000              0.000000          0.000106
# 88          0.000000              0.000668          0.000164
# 89          0.000000              0.003074          0.000617
#
#     net_pyruvic_acid_cmol  net_succinic_acid_cmol
# 0                0.000732                0.000000
# 1                0.000050                0.000000
# 2                0.000050                0.000000
# 3                0.000050                0.000000
# 4                0.000050                0.002502
# ..                    ...                     ...
# 85               0.000746                0.000000
# 86               0.000052                0.000000
# 87               0.000052                0.000000
# 88               0.000052                0.000510
# 89               0.000383                0.001679
#
# [90 rows x 88 columns]

# %% [markdown]
# #### CTR_int, Base volume, and OTR_int from online data into offline data

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values with previous value
df['Formed_CO2'] = df['Formed_CO2'].fillna(method='ffill')
df['Consumed_O2'] = df['Consumed_O2'].fillna(method='ffill')
df['Base_volume'] = df['Base_volume'].fillna(method='ffill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Formed_CO2','Consumed_O2','Base_volume']]
offline_df = pd.concat([offline_df,df[['Formed_CO2','Consumed_O2','Base_volume']]],axis=1)

# %%
offline_df
# Out:
#             Timepoint Sample       Experiment  \
# 0   DDB_PD_117_AMBR_R11__S01  DDB_PD_117_AMBR
# 1   DDB_PD_117_AMBR_R11__S02  DDB_PD_117_AMBR
# 2   DDB_PD_117_AMBR_R11__S03  DDB_PD_117_AMBR
# 3   DDB_PD_117_AMBR_R11__S04  DDB_PD_117_AMBR
# 4   DDB_PD_117_AMBR_R11__S05  DDB_PD_117_AMBR
# ..                       ...              ...
# 85  DDB_PD_126_AMBR_R16__S01  DDB_PD_126_AMBR
# 86  DDB_PD_126_AMBR_R16__S02  DDB_PD_126_AMBR
# 87  DDB_PD_126_AMBR_R16__S03  DDB_PD_126_AMBR
# 88  DDB_PD_126_AMBR_R16__S04  DDB_PD_126_AMBR
# 89  DDB_PD_126_AMBR_R16__S05  DDB_PD_126_AMBR
#
#                            Parent Culture Reactor/Plate/Flask Number  \
# 0   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 1   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 2   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 3   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# 4   DDB_PD_117_AMBR_HMP3071-003_R11_Main_                        R11
# ..                                    ...                        ...
# 85   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 86   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 87   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 88   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
# 89   DDB_PD_126_AMBR_SDT714-001_R16_Main_                        R16
#
#    Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  D-glucose [g/L]  \
# 0            S01      12.276657                 7.0    6.940        13.698200
# 1            S02      16.779256                 5.0   30.750         0.000000
# 2            S03      36.846045                 3.5   60.800         0.000000
# 3            S04      56.969901                 3.5   99.950         0.000000
# 4            S05      77.008533                 7.5  168.500         0.000000
# ..           ...            ...                 ...      ...              ...
# 85           S01      12.566374                 7.0    3.175        14.802268
# 86           S02      20.938572                 5.0   28.100         0.000000
# 87           S03      40.981357                 5.5   68.550         0.000000
# 88           S04      60.981844                 5.5  102.800         0.000000
# 89           S05      80.980182                 7.5  168.900         0.000000
#
#     acetic acid [g/L]  ...  net_acetic_acid_cmol  net_citric_acid_cmol  \
# 0            0.426389  ...              0.001444              0.001397
# 1            0.000000  ...              0.000099              0.001514
# 2            0.000000  ...              0.000099              0.001818
# 3            0.354635  ...              0.001452              0.002332
# 4            0.910389  ...              0.005104              0.005597
# ..                ...  ...                   ...                   ...
# 85           0.321480  ...              0.001071              0.000628
# 86           0.080446  ...              0.000333              0.000636
# 87           0.062385  ...              0.000290              0.000968
# 88           0.460868  ...              0.001804              0.001473
# 89           1.054493  ...              0.005659              0.002839
#
#     net_ethanol_cmol  net_formic_acid_cmol  net_lactate_cmol  \
# 0           0.000502              0.000527          0.000000
# 1           0.000035              0.000036          0.000000
# 2           0.000035              0.000036          0.000000
# 3           0.000035              0.000565          0.000000
# 4           0.000035              0.002218          0.000937
# ..               ...                   ...               ...
# 85          0.000000              0.000000          0.000000
# 86          0.000000              0.000000          0.000000
# 87          0.000000              0.000000          0.000106
# 88          0.000000              0.000668          0.000164
# 89          0.000000              0.003074          0.000617
#
#     net_pyruvic_acid_cmol  net_succinic_acid_cmol  Formed_CO2  Consumed_O2  \
# 0                0.000732                0.000000    0.004647     0.004570
# 1                0.000050                0.000000    0.022953     0.021420
# 2                0.000050                0.000000    0.079981     0.079076
# 3                0.000050                0.000000    0.260982     0.255781
# 4                0.000050                0.002502    0.745764     0.729213
# ..                    ...                     ...         ...          ...
# 85               0.000746                0.000000    0.001641     0.001335
# 86               0.000052                0.000000    0.023258     0.022425
# 87               0.000052                0.000000    0.079510     0.087530
# 88               0.000052                0.000510    0.255377     0.271000
# 89               0.000383                0.001679    0.743310     0.775436
#
#     Base_volume
# 0      0.453535
# 1      2.105600
# 2      4.566529
# 3     10.682854
# 4     24.165175
# ..          ...
# 85     0.272682
# 86     2.412398
# 87     5.130884
# 88    11.405527
# 89    24.475285
#
# [90 rows x 91 columns]

# %% [markdown]
# ## Export data

# %%
online_df.iloc[::5].to_excel('../../data/processed_fermentation_data/exponential_fed-batch_scale-down_online_data.xlsx',index=False)
# online_df.to_excel('../../data/processed_fermentation_data/exponential_fed-batch_scale-down_online_data.xlsx',index=False)

# %%
offline_df.to_excel('../../data/processed_fermentation_data/exponential_fed-batch_scale-down_offline_data.xlsx',index=False)
