# %% [markdown]
# # Fermentation data import and export

# %% [markdown]
# ## 1. Imports and directory definitions

# %%
import pandas as pd # pandas for tabular data manipulation
import numpy as np  # numpy for numerical operations
import glob
import os
from pandas import ExcelWriter
import openpyxl

data_folder = '../../data/'
fieldlist_path = 'fieldlist/fieldlist_v1.xlsx'
od_cal_file = '2021-10-04_OD_calibration_file.xlsx'

# %% [markdown]
# ## 2. Experient name definition

# %%
experiment = 'DDB_PD_117_AMBR'

# %% [markdown]
# ## 3. Import data

# %% [markdown]
# ### 3.1 Main cultures metadata

# %%
# get the path to experiment in the LIMS file folder
experiment_file = data_folder+'LIMS_data/'+experiment+'_LIMS.xlsx'
# import the data from the main culture sheet and drop any column that has only NaNs
meta_data = pd.read_excel(experiment_file, sheet_name='main culture').dropna(how='all', axis=1)
    
# cultures.index = range(0,len(cultures.index)) # updating the index of the dataframe
meta_data.rename(columns={'Sample ID': 'Parent Culture'}, inplace=True)
meta_data.sort_values('Reactor/Plate/Flask Number',inplace=True)
meta_data = meta_data.reset_index().drop('index',axis=1)
meta_data
# Out:
#                            Parent Culture Base Medium  \
# 0     DDB_PD_117_AMBR_DDB35-005_R05_Main_  DDB_BM_016
# 1     DDB_PD_117_AMBR_DDB35-005_R06_Main_  DDB_BM_016
# 2     DDB_PD_117_AMBR_DDB35-005_R07_Main_  DDB_BM_016
# 3     DDB_PD_117_AMBR_DDB35-005_R08_Main_  DDB_BM_016
# 4     DDB_PD_117_AMBR_DDB35-005_R09_Main_  DDB_BM_016
# 5     DDB_PD_117_AMBR_DDB35-005_R10_Main_  DDB_BM_016
# 6   DDB_PD_117_AMBR_HMP3071-003_R11_Main_  DDB_BM_016
# 7   DDB_PD_117_AMBR_HMP3071-003_R12_Main_  DDB_BM_016
# 8   DDB_PD_117_AMBR_HMP3071-003_R13_Main_  DDB_BM_016
# 9   DDB_PD_117_AMBR_HMP3071-003_R14_Main_  DDB_BM_016
# 10  DDB_PD_117_AMBR_HMP3071-003_R15_Main_  DDB_BM_016
# 11  DDB_PD_117_AMBR_HMP3071-003_R16_Main_  DDB_BM_016
#
#    Container ID (calculated) Container Type Control? Culture Type  \
# 0                        R05       AMBR 250       No         Main
# 1                        R06       AMBR 250       No         Main
# 2                        R07       AMBR 250       No         Main
# 3                        R08       AMBR 250       No         Main
# 4                        R09       AMBR 250       No         Main
# 5                        R10       AMBR 250       No         Main
# 6                        R11       AMBR 250       No         Main
# 7                        R12       AMBR 250       No         Main
# 8                        R13       AMBR 250       No         Main
# 9                        R14       AMBR 250       No         Main
# 10                       R15       AMBR 250       No         Main
# 11                       R16       AMBR 250       No         Main
#
#          Experiment Feed Medium #1 Reactor/Plate/Flask Number  Replicate #  \
# 0   DDB_PD_117_AMBR     DDB_FM_015                        R05            1
# 1   DDB_PD_117_AMBR     DDB_FM_015                        R06            1
# 2   DDB_PD_117_AMBR     DDB_FM_015                        R07            1
# 3   DDB_PD_117_AMBR     DDB_FM_015                        R08            1
# 4   DDB_PD_117_AMBR     DDB_FM_015                        R09            1
# 5   DDB_PD_117_AMBR     DDB_FM_015                        R10            1
# 6   DDB_PD_117_AMBR     DDB_FM_015                        R11            1
# 7   DDB_PD_117_AMBR     DDB_FM_015                        R12            1
# 8   DDB_PD_117_AMBR     DDB_FM_015                        R13            1
# 9   DDB_PD_117_AMBR     DDB_FM_015                        R14            1
# 10  DDB_PD_117_AMBR     DDB_FM_015                        R15            1
# 11  DDB_PD_117_AMBR     DDB_FM_015                        R16            1
#
#     ... Culture Volume Unit Temperature Setpoint (C)  \
# 0   ...                  mL                       30
# 1   ...                  mL                       30
# 2   ...                  mL                       30
# 3   ...                  mL                       30
# 4   ...                  mL                       30
# 5   ...                  mL                       30
# 6   ...                  mL                       30
# 7   ...                  mL                       30
# 8   ...                  mL                       30
# 9   ...                  mL                       30
# 10  ...                  mL                       30
# 11  ...                  mL                       30
#
#                      Feed #1 Profile pH Setpoint  pH Control Base Solution  \
# 0   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 1   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 2   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 3   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 4   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 5   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 6   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 7   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 8   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 9   DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 10  DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
# 11  DDB_Feed_Profile_DDB_PD_117_AMBR         6.5     Ammonium hydroxide 8%
#
#    Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0                     0.15                     0.15
# 1                     0.15                     0.15
# 2                     0.15                     0.15
# 3                     0.15                     0.15
# 4                     0.15                     0.15
# 5                     0.15                     0.15
# 6                     0.15                     0.15
# 7                     0.15                     0.15
# 8                     0.15                     0.15
# 9                     0.15                     0.15
# 10                    0.15                     0.15
# 11                    0.15                     0.15
#
#    Minimum Stirring or Shaking Speed (rpm)  \
# 0                                     4000
# 1                                     4000
# 2                                     4000
# 3                                     4000
# 4                                     4000
# 5                                     4000
# 6                                     4000
# 7                                     4000
# 8                                     4000
# 9                                     4000
# 10                                    4000
# 11                                    4000
#
#     Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type
# 0                                      4000                Air
# 1                                      4000                Air
# 2                                      4000                Air
# 3                                      4000                Air
# 4                                      4000                Air
# 5                                      4000                Air
# 6                                      4000                Air
# 7                                      4000                Air
# 8                                      4000                Air
# 9                                      4000                Air
# 10                                     4000                Air
# 11                                     4000                Air
#
# [12 rows x 23 columns]

# %% [markdown]
# ### 3.1 Online data

# %%
online_data_dir = 'online_data_9s_interpolated/'
csv_prefix = '_online_stacked_9s.csv'

# %%
# import fieldlist
fieldlist = pd.read_excel(fieldlist_path)
# initialize an empty DataFrame with columns from the variables specified in the fieldlist
online_data = pd.DataFrame(columns=list(fieldlist.new_variable_name))

# %%
ambr_df = pd.read_csv(data_folder+ online_data_dir + str(experiment) + csv_prefix)

for column in list(online_data.columns): # iterate over the columns of the temporary dataframe. The columns are the variable names of the online data.
    # match the column name (new_variable_name) to the name given by ambr250. Then assign the ambr250 online data to the matching column in the temp_df
    online_data[column] = ambr_df[fieldlist[fieldlist.new_variable_name == column].AMBR_name.iloc[0]]

# adding a column with the experiment name
online_data['Experiment'] = experiment

# Converting the bioreactor naming format in the temporary ambr df
for i in range(1,10):
    ambr_df['Batch ID'] = ambr_df['Batch ID'].replace('Bioreactor '+str(i),'R0'+str(i))
for i in range(10,25):
    ambr_df['Batch ID'] = ambr_df['Batch ID'].replace('Bioreactor '+str(i),'R'+str(i))

# adding a column with the Reactor Number
online_data['Reactor/Plate/Flask Number'] = ambr_df['Batch ID'] # adding a column with the reactor ID
    
# dropping some unnecessary rows from the online data DataFrame:
online_data.dropna(axis=0, subset=['Inlet_air_O2'],inplace=True)
    
# updating index
online_data.index = range(0,len(online_data.index)) # updating the index of the dataframe
    
# Merging online data with cultures metadata
online_data = pd.merge(left=online_data,right=meta_data)
    
# phase annotation
feed_vol_list = online_data['Feed_volume'].tolist()
phase_list = ['feed' if i > 0.0 else 'batch' for i in feed_vol_list]
online_data['Phase'] = phase_list
online_data.head()
# Out:
#      Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0  0.0000  99.384914  6.529322    1002.000000    29.989540  0.547836
# 1  0.0025  98.465270  6.534555    1002.000000    29.982064  2.383883
# 2  0.0050  97.813961  6.535457     998.741950    29.974569  2.806834
# 3  0.0075  97.375563  6.534708     998.048215    29.969999  2.727807
# 4  0.0100  97.116550  6.534041    1003.000000    29.969591  2.704525
#
#      Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0  100.050691          0.0         20.95  20.702183  ...
# 1   99.785299          0.0         20.95  20.705174  ...
# 2   99.817884          0.0         20.95  20.708171  ...
# 3   99.954108          0.0         20.95  20.707951  ...
# 4  100.064567          0.0         20.95  20.702877  ...
#
#    Temperature Setpoint (C)                   Feed #1 Profile  pH Setpoint  \
# 0                        30  DDB_Feed_Profile_DDB_PD_117_AMBR          6.5
# 1                        30  DDB_Feed_Profile_DDB_PD_117_AMBR          6.5
# 2                        30  DDB_Feed_Profile_DDB_PD_117_AMBR          6.5
# 3                        30  DDB_Feed_Profile_DDB_PD_117_AMBR          6.5
# 4                        30  DDB_Feed_Profile_DDB_PD_117_AMBR          6.5
#
#    pH Control Base Solution  Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0     Ammonium hydroxide 8%                     0.15                     0.15
# 1     Ammonium hydroxide 8%                     0.15                     0.15
# 2     Ammonium hydroxide 8%                     0.15                     0.15
# 3     Ammonium hydroxide 8%                     0.15                     0.15
# 4     Ammonium hydroxide 8%                     0.15                     0.15
#
#    Minimum Stirring or Shaking Speed (rpm)  \
# 0                                     4000
# 1                                     4000
# 2                                     4000
# 3                                     4000
# 4                                     4000
#
#    Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type  Phase
# 0                                     4000                Air  batch
# 1                                     4000                Air  batch
# 2                                     4000                Air  batch
# 3                                     4000                Air  batch
# 4                                     4000                Air  batch
#
# [5 rows x 48 columns]

# %% [markdown]
# ### 3.2 Offline data

# %% [markdown]
# #### 3.2.1 Timepoint data

# %%
timepoint_cols = ['Entity','Experiment','Parent Culture','Reactor/Plate Number','Timepoint (#)','Timepoint (h)','Volume','OD']
file = data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx' # get the path to experimentin the LIMS file folder

timepoint_data = pd.read_excel(file, sheet_name='timepoint samples')[timepoint_cols] # importing timepoint data from one experiment into a temporary DFF

# renaming some of the columns in the dataframe and reindexing
timepoint_data.rename(columns={"Entity": "Timepoint Sample", "Reactor/Plate Number": "Reactor/Plate/Flask Number", "Volume": "Sample volume (mL)"},inplace=True)
timepoint_data = timepoint_data.reset_index().drop('index',axis=1)
timepoint_data.head()
# Out:
#            Timepoint Sample       Experiment  \
# 0  DDB_PD_117_AMBR_R05__S01  DDB_PD_117_AMBR
# 1  DDB_PD_117_AMBR_R05__S02  DDB_PD_117_AMBR
# 2  DDB_PD_117_AMBR_R05__S03  DDB_PD_117_AMBR
# 3  DDB_PD_117_AMBR_R05__S04  DDB_PD_117_AMBR
# 4  DDB_PD_117_AMBR_R05__S05  DDB_PD_117_AMBR
#
#                         Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 1  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 2  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 3  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 4  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD
# 0           S01      12.085309                 7.0   13.49
# 1           S02      15.372317                 5.0   36.85
# 2           S03      35.501496                 3.5   88.00
# 3           S04      55.554583                 3.5  164.60
# 4           S05      75.579442                 7.5  280.80

# %% [markdown]
# #### 3.2.2 Analytical data

# %%
analytical_cols = ['Name', 'Analysis Type', 'Cellular Compartment', 'Dilution Factor','Experiment', 'Parent Culture', 'Sample Prep Date', 'Timepoint (h)', 'Timepoint Sample', 'compound_name', 'concentration','concentration_unit']
    
analytical_data = pd.DataFrame(columns=analytical_cols) # initializing an empty DF for timepoint_data
file = data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx' # get the path to experiment in the LIMS file folder

analytical_data = pd.read_excel(file, sheet_name='analytical samples')[analytical_cols] # importing timepoint data from one experiment into a temporary DF

# renaming one of the columns in the dataframe and reindexing
analytical_data.rename(columns={"Name": "Analytical Sample"},inplace=True)
analytical_data = analytical_data.reset_index().drop('index',axis=1)

# correcting for the dilution factor, then dropping the dilution factor
analytical_data['concentration'] = analytical_data['concentration'] * analytical_data['Dilution Factor']
analytical_data.drop(['Dilution Factor'], axis=1, inplace=True)
# removing any analytical data not obtained from a main culture sample
analytical_data = analytical_data[analytical_data['Parent Culture'].notnull()]
analytical_data.head()
# Out:
#                   Analytical Sample Analysis Type  Cellular Compartment  \
# 27  DDB_PD_117_AMBR_R05__S01_SOA_#1           SOA  Extracellular Region
# 28  DDB_PD_117_AMBR_R05__S01_SOA_#1           SOA  Extracellular Region
# 29  DDB_PD_117_AMBR_R05__S01_SOA_#1           SOA  Extracellular Region
# 30  DDB_PD_117_AMBR_R05__S01_SOA_#1           SOA  Extracellular Region
# 31  DDB_PD_117_AMBR_R05__S01_SOA_#1           SOA  Extracellular Region
#
#          Experiment                       Parent Culture Sample Prep Date  \
# 27  DDB_PD_117_AMBR  DDB_PD_117_AMBR_DDB35-005_R05_Main_       2023-01-17
# 28  DDB_PD_117_AMBR  DDB_PD_117_AMBR_DDB35-005_R05_Main_       2023-01-17
# 29  DDB_PD_117_AMBR  DDB_PD_117_AMBR_DDB35-005_R05_Main_       2023-01-17
# 30  DDB_PD_117_AMBR  DDB_PD_117_AMBR_DDB35-005_R05_Main_       2023-01-17
# 31  DDB_PD_117_AMBR  DDB_PD_117_AMBR_DDB35-005_R05_Main_       2023-01-17
#
#     Timepoint (h)          Timepoint Sample                   compound_name  \
# 27      12.085309  DDB_PD_117_AMBR_R05__S01                     citric acid
# 28      12.085309  DDB_PD_117_AMBR_R05__S01                     acetic acid
# 29      12.085309  DDB_PD_117_AMBR_R05__S01                     formic acid
# 30      12.085309  DDB_PD_117_AMBR_R05__S01                    pyruvic acid
# 31      12.085309  DDB_PD_117_AMBR_R05__S01  potassium dihydrogen phosphate
#
#     concentration concentration_unit
# 27       0.433204                g/L
# 28       0.771709                g/L
# 29       0.582330                g/L
# 30       0.000000                g/L
# 31      11.311882                g/L

# %% [markdown]
# ##### 3.2.2.1 Pivot analytical data

# %%
analytical_data['compound_name_and_unit'] = analytical_data['compound_name'] + ' [' + analytical_data['concentration_unit'] + ']'

analytical_data_pivot = analytical_data.pivot(index='Timepoint Sample', columns=['compound_name_and_unit'], values='concentration')
analytical_data_pivot['Timepoint Sample'] = analytical_data_pivot.index

analytical_data_pivot.index.name = None
analytical_data_pivot.columns.name = None
analytical_data_pivot = analytical_data_pivot.reset_index().drop('index',axis=1)

analytical_data_pivot.head()
# Out:
#    D-glucose [g/L]  acetic acid [g/L]  citric acid [g/L]  ethanol [g/L]  \
# 0        11.143793           0.771709           0.433204       0.139903
# 1         0.000000           0.292768           0.445241       0.000000
# 2         0.000000           0.000000           0.288230       0.000000
# 3         0.000000           0.000000           0.000000       0.000000
# 4         0.000000           0.000000           0.000000       0.000000
#
#    formic acid [g/L]  lactate [g/L]  potassium dihydrogen phosphate [g/L]  \
# 0            0.58233       0.330215                             11.311882
# 1            0.00000       0.000000                             10.999189
# 2            0.00000       0.000000                              8.292849
# 3            0.00000       0.000000                              5.798261
# 4            0.00000       0.104975                              2.972819
#
#    pyruvic acid [g/L]  succinic acid [g/L]  tryptophan [g/L]  \
# 0                 0.0             0.000000               NaN
# 1                 0.0             0.000000               NaN
# 2                 0.0             0.000000               NaN
# 3                 0.0             0.000000               NaN
# 4                 0.0             0.348699               NaN
#
#            Timepoint Sample
# 0  DDB_PD_117_AMBR_R05__S01
# 1  DDB_PD_117_AMBR_R05__S02
# 2  DDB_PD_117_AMBR_R05__S03
# 3  DDB_PD_117_AMBR_R05__S04
# 4  DDB_PD_117_AMBR_R05__S05

# %% [markdown]
# #### 3.2.3 Trace_metal_data

# %%
trace_metal_data = pd.read_excel(data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx', sheet_name='trace metal export')
trace_metal_data.rename(columns={'Name': 'Analytical Sample'}, inplace=True)

# timepoint_samples_temp = []
# for i in df_tm['Analytical Sample'].to_list():
#     timepoint_samples_temp.append(i.split('_TM')[0])

# df_tm['Timepoint Sample'] = timepoint_samples_temp
trace_metal_data['Timepoint Sample'] = trace_metal_data['Analytical Sample'].apply(lambda x: pd.Series(str(x).split("_TM")[0]))
trace_metal_data.head()
# Out:
# Empty DataFrame
# Columns: [Analytical Sample, compound_name, concentration, concentration_unit, Timepoint Sample]
# Index: []

# %% [markdown]
# ##### 3.2.2.1 Pivot trace metal data

# %%
trace_metal_data['compound_name_and_unit'] = trace_metal_data['compound_name'] + ' [' + trace_metal_data['concentration_unit'] + ']'

trace_metal_data_pivot = trace_metal_data.pivot(index='Timepoint Sample', columns=['compound_name_and_unit'], values='concentration')
trace_metal_data_pivot['Timepoint Sample'] = trace_metal_data_pivot.index

trace_metal_data_pivot.index.name = None
trace_metal_data_pivot.columns.name = None
trace_metal_data_pivot = trace_metal_data_pivot.reset_index().drop('index',axis=1)

trace_metal_data_pivot.head()
# Out:
# Empty DataFrame
# Columns: [Timepoint Sample]
# Index: []

# %% [markdown]
# #### 3.2.4 Custom data

# %%
try:
    custom_data = pd.read_excel(data_folder+'/custom_data_import_files/'+experiment+'_custom.xlsx')
    custom_data.head()
except:
    custom_data = pd.DataFrame(columns=['Timepoint Sample'])
    
custom_data
# Out:
#             Timepoint Sample  CDW_1 [g/L]  CDW_2 [g/L]  CDW_3 [g/L]  \
# 0   DDB_PD_117_AMBR_R05__S01         4.50         4.50         4.30
# 1   DDB_PD_117_AMBR_R05__S02        10.60        10.70        10.00
# 2   DDB_PD_117_AMBR_R05__S03        25.25        25.00        24.75
# 3   DDB_PD_117_AMBR_R05__S04        52.60        52.40        52.80
# 4   DDB_PD_117_AMBR_R05__S05        92.30        92.30        91.80
# 5   DDB_PD_117_AMBR_R06__S01         4.50         4.90         4.40
# 6   DDB_PD_117_AMBR_R06__S02        10.00        10.70         9.90
# 7   DDB_PD_117_AMBR_R06__S03        25.75        24.75        26.50
# 8   DDB_PD_117_AMBR_R06__S04        53.60        53.80        54.40
# 9   DDB_PD_117_AMBR_R06__S05        93.20        92.80        92.60
# 10  DDB_PD_117_AMBR_R07__S01         4.80         4.60         4.50
# 11  DDB_PD_117_AMBR_R07__S02        10.40         9.80         9.80
# 12  DDB_PD_117_AMBR_R07__S03        25.00        28.50        26.00
# 13  DDB_PD_117_AMBR_R07__S04        52.80        55.00        52.00
# 14  DDB_PD_117_AMBR_R07__S05        89.80        91.70        91.10
# 15  DDB_PD_117_AMBR_R08__S01         4.60         5.00         5.00
# 16  DDB_PD_117_AMBR_R08__S02        10.20         9.90         9.70
# 17  DDB_PD_117_AMBR_R08__S03        24.25        25.75        26.00
# 18  DDB_PD_117_AMBR_R08__S04        52.80        53.80        52.60
# 19  DDB_PD_117_AMBR_R08__S05        85.50        87.80        87.90
# 20  DDB_PD_117_AMBR_R09__S01         4.80         5.10         5.00
# 21  DDB_PD_117_AMBR_R09__S02        11.10        10.80        10.30
# 22  DDB_PD_117_AMBR_R09__S03        25.75        26.50        24.00
# 23  DDB_PD_117_AMBR_R09__S04        54.00        54.20        51.60
# 24  DDB_PD_117_AMBR_R09__S05        87.50        87.30        87.00
# 25  DDB_PD_117_AMBR_R10__S01         4.85         5.90         4.70
# 26  DDB_PD_117_AMBR_R10__S02        10.60        10.50        10.30
# 27  DDB_PD_117_AMBR_R10__S03        26.00        24.75        26.75
# 28  DDB_PD_117_AMBR_R10__S04        53.00        52.80        53.20
# 29  DDB_PD_117_AMBR_R10__S05        85.80        87.60        86.20
# 30  DDB_PD_117_AMBR_R11__S01         2.80         2.80         2.50
# 31  DDB_PD_117_AMBR_R11__S02         9.50         9.50         9.30
# 32  DDB_PD_117_AMBR_R11__S03        22.00        21.25          NaN
# 33  DDB_PD_117_AMBR_R11__S04        33.20        33.60        33.00
# 34  DDB_PD_117_AMBR_R11__S05        52.50        52.50        52.70
# 35  DDB_PD_117_AMBR_R12__S01         2.90         2.90         3.30
# 36  DDB_PD_117_AMBR_R12__S02         9.70        10.00         9.90
# 37  DDB_PD_117_AMBR_R12__S03        18.75        21.00        19.75
# 38  DDB_PD_117_AMBR_R12__S04        33.80        33.20        33.60
# 39  DDB_PD_117_AMBR_R12__S05        52.40        52.20        52.30
# 40  DDB_PD_117_AMBR_R13__S01         3.40         3.20         3.60
# 41  DDB_PD_117_AMBR_R13__S02        10.10         9.80         9.40
# 42  DDB_PD_117_AMBR_R13__S03        21.25        21.50        22.25
# 43  DDB_PD_117_AMBR_R13__S04        33.80        34.40        34.80
# 44  DDB_PD_117_AMBR_R13__S05        54.00        53.70        54.30
# 45  DDB_PD_117_AMBR_R14__S01         4.10         3.60         3.40
# 46  DDB_PD_117_AMBR_R14__S02        10.10         9.40         9.60
# 47  DDB_PD_117_AMBR_R14__S03        21.00        20.75        20.75
# 48  DDB_PD_117_AMBR_R14__S04        31.80        32.00        32.80
# 49  DDB_PD_117_AMBR_R14__S05        46.50        46.70        46.80
# 50  DDB_PD_117_AMBR_R15__S01         3.60         3.80         3.90
# 51  DDB_PD_117_AMBR_R15__S02         9.60         9.40         9.60
# 52  DDB_PD_117_AMBR_R15__S03        20.25        19.75        19.25
# 53  DDB_PD_117_AMBR_R15__S04        32.00        32.00        32.80
# 54  DDB_PD_117_AMBR_R15__S05        47.80        47.50        47.80
# 55  DDB_PD_117_AMBR_R16__S01         3.40         2.80         3.30
# 56  DDB_PD_117_AMBR_R16__S02        10.10         9.70         9.70
# 57  DDB_PD_117_AMBR_R16__S03        20.75        19.50        18.50
# 58  DDB_PD_117_AMBR_R16__S04        34.20        33.20        30.80
# 59  DDB_PD_117_AMBR_R16__S05        46.80        48.10        47.60
#
#     Ammonium [g/L]
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4         0.765575
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9         0.743857
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14        0.850612
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19        0.675840
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24        0.631088
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29        0.711027
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34        1.830674
# 35             NaN
# 36             NaN
# 37             NaN
# 38             NaN
# 39        1.743293
# 40             NaN
# 41             NaN
# 42             NaN
# 43             NaN
# 44        1.814755
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49        1.890965
# 50             NaN
# 51             NaN
# 52             NaN
# 53             NaN
# 54        1.803368
# 55             NaN
# 56             NaN
# 57             NaN
# 58             NaN
# 59        2.038687

# %% [markdown]
# #### 3.2.5 Merging all offline data

# %%
ac_merge = pd.merge(left=analytical_data_pivot, right=trace_metal_data_pivot, how='left')
custom_merge = pd.merge(left=ac_merge, right=custom_data, how='left')
offline_data = pd.merge(left=timepoint_data, right=custom_merge, how='left')
offline_data.head()
# Out:
#            Timepoint Sample       Experiment  \
# 0  DDB_PD_117_AMBR_R05__S01  DDB_PD_117_AMBR
# 1  DDB_PD_117_AMBR_R05__S02  DDB_PD_117_AMBR
# 2  DDB_PD_117_AMBR_R05__S03  DDB_PD_117_AMBR
# 3  DDB_PD_117_AMBR_R05__S04  DDB_PD_117_AMBR
# 4  DDB_PD_117_AMBR_R05__S05  DDB_PD_117_AMBR
#
#                         Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 1  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 2  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 3  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
# 4  DDB_PD_117_AMBR_DDB35-005_R05_Main_                        R05
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD  D-glucose [g/L]  \
# 0           S01      12.085309                 7.0   13.49        11.143793
# 1           S02      15.372317                 5.0   36.85         0.000000
# 2           S03      35.501496                 3.5   88.00         0.000000
# 3           S04      55.554583                 3.5  164.60         0.000000
# 4           S05      75.579442                 7.5  280.80         0.000000
#
#    acetic acid [g/L]  ...  formic acid [g/L]  lactate [g/L]  \
# 0           0.771709  ...            0.58233       0.330215
# 1           0.292768  ...            0.00000       0.000000
# 2           0.000000  ...            0.00000       0.000000
# 3           0.000000  ...            0.00000       0.000000
# 4           0.000000  ...            0.00000       0.104975
#
#    potassium dihydrogen phosphate [g/L]  pyruvic acid [g/L]  \
# 0                             11.311882                 0.0
# 1                             10.999189                 0.0
# 2                              8.292849                 0.0
# 3                              5.798261                 0.0
# 4                              2.972819                 0.0
#
#    succinic acid [g/L]  tryptophan [g/L]  CDW_1 [g/L]  CDW_2 [g/L]  \
# 0             0.000000               NaN         4.50          4.5
# 1             0.000000               NaN        10.60         10.7
# 2             0.000000               NaN        25.25         25.0
# 3             0.000000               NaN        52.60         52.4
# 4             0.348699               NaN        92.30         92.3
#
#    CDW_3 [g/L]  Ammonium [g/L]
# 0         4.30             NaN
# 1        10.00             NaN
# 2        24.75             NaN
# 3        52.80             NaN
# 4        91.80        0.765575
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 4. Export data

# %%
meta_data.to_csv(experiment + '_meta_data_export.csv',index=False)
offline_data.to_csv(experiment + '_offline_data_export.csv',index=False)
online_data.to_csv(experiment + '_online_data_export.csv',index=False)
