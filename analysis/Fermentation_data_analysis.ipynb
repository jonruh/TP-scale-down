# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from matplotlib import cm

import scipy
# .stats.ttest_ind

from matplotlib.patches import Patch
from matplotlib.patches import Circle
from matplotlib.lines import Line2D

from matplotlib.patches import ConnectionPatch

# %%
offline_data = pd.read_excel("../data/processed_fermentation_data/exponential_fed-batch_scale-down_offline_data.xlsx")
online_data = pd.read_excel("../data/processed_fermentation_data/exponential_fed-batch_scale-down_online_data.xlsx")
online_data["new_feed_time"] = np.round(np.round(online_data["feed_time"]/0.0125)*0.0125 + np.round(online_data["feed_time_adjustment_for_equal_feed_volume"]/0.0125)*0.0125,4)
online_data["hue"] = online_data["Strain"]+":"+online_data["Condition"]
meta_data = pd.read_excel("../data/processed_fermentation_data/exponential_fed-batch_scale-down_meta_data.xlsx")

# %% [markdown]
# # Timeplots

# %% [markdown]
# ## Biomass

# %%
data = offline_data

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="net_biomass_cmol",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\4264519012.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='net_biomass_cmol'>

# %% [markdown]
# ## CO2

# %%
data = online_data

# %%
sns.lineplot(
    data=data,
    x="feed_time",
    y="Formed_CO2",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    linewidth = 1,
    errorbar = 'sd'
)

# plt.yscale("log")
# Out:
# <Axes: xlabel='feed_time', ylabel='Formed_CO2'>

# %%
data = offline_data

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="Formed_CO2",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\3914783718.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='Formed_CO2'>

# %% [markdown]
# ## O2

# %%
data = offline_data

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="Consumed_O2",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1642251641.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='Consumed_O2'>

# %% [markdown]
# ## Tryptophan

# %%
data = offline_data

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="net_tryptophan_cmol",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    # linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\823981154.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='net_tryptophan_cmol'>

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="tryptophan [g/L]",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    # linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1967655170.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='tryptophan [g/L]'>

# %% [markdown]
# ## Acetate

# %%
data = offline_data

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="net_acetic_acid_cmol",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    # linewidth = 1,
    errorbar = 'sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1454816757.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='net_acetic_acid_cmol'>

# %%
sns.lineplot(
    data=data,
    x="average_feed_time",
    y="acetic acid [g/L]",
    hue="Strain",
    style='Condition',
    dashes=[(2, 0),(2, 2)],
    # linewidth = 1
    errorbar = 'sd',,
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0
    },
    # marker styles
    markersize=5,
    markers=['o'],
    markeredgecolor=None
)

# plt.yscale("log")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\298025236.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# <Axes: xlabel='average_feed_time', ylabel='acetic acid [g/L]'>

# %% [markdown]
# # Yield barpots

# %%
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Yss [molC/molC]"] = offline_data["net_succinic_acid_cmol"]/offline_data["net_glucose_cmol"]

# %% [markdown]
# ## Ysx

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Ysx [molC/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Ysx [molC/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Ysx [molC/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.612985
# 1    DDB35  scale-down         0.574709
# 2  HMP3071     control         0.325348
# 3  HMP3071  scale-down         0.286608

# %%
data.groupby(["Strain", "Condition"])["Ysx [molC/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.006192
# 1    DDB35  scale-down         0.003000
# 2  HMP3071     control         0.006437
# 3  HMP3071  scale-down         0.003097

# %% [markdown]
# ## Ysc

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Ysc [molC/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Ysc [molC/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Ysc [molC/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.612985
# 1    DDB35  scale-down         0.574709
# 2  HMP3071     control         0.325348
# 3  HMP3071  scale-down         0.286608

# %%
data.groupby(["Strain", "Condition"])["Ysc [molC/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.006192
# 1    DDB35  scale-down         0.003000
# 2  HMP3071     control         0.006437
# 3  HMP3071  scale-down         0.003097

# %% [markdown]
# ## Yso

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Yso [mol/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Yso [mol/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Yso [mol/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.612985
# 1    DDB35  scale-down         0.574709
# 2  HMP3071     control         0.325348
# 3  HMP3071  scale-down         0.286608

# %%
data.groupby(["Strain", "Condition"])["Yso [mol/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.006192
# 1    DDB35  scale-down         0.003000
# 2  HMP3071     control         0.006437
# 3  HMP3071  scale-down         0.003097

# %% [markdown]
# ## Yst

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Yst [molC/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Yst [molC/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Yst [molC/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.612985
# 1    DDB35  scale-down         0.574709
# 2  HMP3071     control         0.325348
# 3  HMP3071  scale-down         0.286608

# %%
data.groupby(["Strain", "Condition"])["Yst [molC/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysx [molC/molC]
# 0    DDB35     control         0.006192
# 1    DDB35  scale-down         0.003000
# 2  HMP3071     control         0.006437
# 3  HMP3071  scale-down         0.003097

# %% [markdown]
# ## Ysa

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Ysa [molC/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Ysa [molC/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Ysa [molC/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysa [molC/molC]
# 0    DDB35     control         0.000447
# 1    DDB35  scale-down         0.000560
# 2  HMP3071     control         0.004318
# 3  HMP3071  scale-down         0.006912

# %%
data.groupby(["Strain", "Condition"])["Ysa [molC/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysa [molC/molC]
# 0    DDB35     control         0.000361
# 1    DDB35  scale-down         0.000495
# 2  HMP3071     control         0.000258
# 3  HMP3071  scale-down         0.000484

# %% [markdown]
# ## Ysp

# %%
data = offline_data[offline_data["Timepoint (#)"] == "S05"]

sns.barplot(
    data=data,
    x="Strain",
    y="Ysp [molC/molC]",
    hue="Condition",
    errorbar="sd"
)
# Out:
# <Axes: xlabel='Strain', ylabel='Ysp [molC/molC]'>

# %%
data.groupby(["Strain", "Condition"])["Ysp [molC/molC]"].mean().reset_index()
# Out:
#     Strain   Condition  Ysp [molC/molC]
# 0    DDB35     control         0.000031
# 1    DDB35  scale-down         0.000039
# 2  HMP3071     control         0.000056
# 3  HMP3071  scale-down         0.000065

# %%
data.groupby(["Strain", "Condition"])["Ysp [molC/molC]"].std().reset_index()
# Out:
#     Strain   Condition  Ysp [molC/molC]
# 0    DDB35     control         0.000027
# 1    DDB35  scale-down         0.000001
# 2  HMP3071     control         0.000010
# 3  HMP3071  scale-down         0.000005

# %% [markdown]
# ## Carbon balance

# %%
c_balance_df = data.groupby(["Strain", "Condition"])[["Ysx [molC/molC]","Ysc [molC/molC]", "Ysp [molC/molC]"]].mean().reset_index()
c_balance_df["C balance [-]"] = c_balance_df["Ysx [molC/molC]"]+c_balance_df["Ysc [molC/molC]"]+c_balance_df["Ysp [molC/molC]"]
c_balance_df
# Out:
#     Strain   Condition  Ysx [molC/molC]  Ysc [molC/molC]  Ysp [molC/molC]  \
# 0    DDB35     control         0.612985         0.419193         0.000031
# 1    DDB35  scale-down         0.574709         0.472561         0.000039
# 2  HMP3071     control         0.325348         0.642952         0.000056
# 3  HMP3071  scale-down         0.286608         0.680284         0.000065
#
#    C balance [-]
# 0       1.032210
# 1       1.047309
# 2       0.968356
# 3       0.966956

# %% [markdown]
# # Figure creation

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=2, ncols=6)

ax1 = fig.add_subplot(spec[0,3:5])
ax1_yield_aux = fig.add_subplot(spec[0,5])
ax1_yield = ax1_yield_aux.twinx()

ax2 = fig.add_subplot(spec[1,:2])
ax2_yield_aux = fig.add_subplot(spec[1,2])
ax2_yield = ax2_yield_aux.twinx()

ax3 = fig.add_subplot(spec[1,3:5])
ax3_yield_aux = fig.add_subplot(spec[1,5])
ax3_yield = ax3_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### Trp plot
############

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_tryptophan_cmol",
    ax=ax1,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Yst [molC/molC]",
    errorbar="sd",
    ax=ax1_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax1_yield.get_legend().remove()

### Biomass plot
############

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_biomass_cmol",
    ax=ax2,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysx [molC/molC]",
    errorbar="sd",
    ax=ax2_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax2_yield.get_legend().remove()

### CO2 plot
############

sns.lineplot(
    data=online_data,
    x="new_feed_time",
    y="Formed_CO2",
    ax=ax3,
    hue="hue",
    # style='Condition',
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    linewidth = 0.5
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysc [molC/molC]",
    errorbar="sd",
    ax=ax3_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax3_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])
ax2.set_xticks([0,20,40,60])
ax3.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])
ax2_yield_aux.set_yticks([])
ax3_yield_aux.set_yticks([])

w=120/25.4
h=70/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Figure1_raw.svg", dpi=900)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1609503905.py:42: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1609503905.py:42: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1609503905.py:82: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\1609503905.py:82: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=2, ncols=6)

ax1 = fig.add_subplot(spec[0,3:5])
ax1_yield_aux = fig.add_subplot(spec[0,5])
ax1_yield = ax1_yield_aux.twinx()

ax2 = fig.add_subplot(spec[1,:2])
ax2_yield_aux = fig.add_subplot(spec[1,2])
ax2_yield = ax2_yield_aux.twinx()

ax3 = fig.add_subplot(spec[1,3:5])
ax3_yield_aux = fig.add_subplot(spec[1,5])
ax3_yield = ax3_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysf [molC/molC]"] = offline_data["net_formic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]



### Acetate plot
################

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_acetic_acid_cmol",
    ax=ax2,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysa [molC/molC]",
    errorbar="sd",
    ax=ax2_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax2_yield.get_legend().remove()

### Formate plot
################

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_formic_acid_cmol",
    ax=ax3,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysf [molC/molC]",
    errorbar="sd",
    ax=ax3_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax3_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])
ax2.set_xticks([0,20,40,60])
ax3.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])
ax2_yield_aux.set_yticks([])
ax3_yield_aux.set_yticks([])

w=120/25.4
h=70/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Figure_acids_raw.svg", dpi=900)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\4004275235.py:45: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\4004275235.py:45: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\4004275235.py:85: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\4004275235.py:85: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(

# %%
sns.lineplot(
    data=online_data,
    x="new_feed_time",
    y="Formed_CO2",
    # ax=ax3,
    hue="hue",
    style='Condition',
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    linewidth = 1
)
# Out:
# <Axes: xlabel='new_feed_time', ylabel='Formed_CO2'>

# %% [markdown]
# # Supplement Figures

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=1, ncols=3)

ax1 = fig.add_subplot(spec[0,:2])
ax1_yield_aux = fig.add_subplot(spec[0,2])
ax1_yield = ax1_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysf [molC/molC]"] = offline_data["net_formic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### Biomass plot
############

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_acetic_acid_cmol",
    ax=ax1,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysa [molC/molC]",
    errorbar="sd",
    ax=ax1_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax1_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])

w=60/25.4
h=35/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Acetate_raw.svg", dpi=900)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2752508083.py:35: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2752508083.py:35: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=1, ncols=3)

ax1 = fig.add_subplot(spec[0,:2])
ax1_yield_aux = fig.add_subplot(spec[0,2])
ax1_yield = ax1_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysf [molC/molC]"] = offline_data["net_formic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### Biomass plot
############

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_formic_acid_cmol",
    ax=ax1,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysf [molC/molC]",
    errorbar="sd",
    ax=ax1_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax1_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])

w=60/25.4
h=35/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Formate_raw.svg", dpi=900)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2526516804.py:35: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2526516804.py:35: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=1, ncols=3)

ax1 = fig.add_subplot(spec[0,:2])
ax1_yield_aux = fig.add_subplot(spec[0,2])
ax1_yield = ax1_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### Biomass plot
############

sns.lineplot(
    data=offline_data,
    x="average_feed_time",
    y="net_pyruvic_acid_cmol",
    ax=ax1,
    hue="hue",
    style='Condition',
    dashes=[(2, 0)],
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    err_style='bars',
    err_kws = {
        'elinewidth':1.0,
        'capsize':2.0,
    },
    markersize=3,
    markers=['o'],
    markeredgecolor=None,
    linewidth = 1
)

sns.barplot(
    data=data,
    x="Strain",
    y="Ysp [molC/molC]",
    errorbar="sd",
    ax=ax1_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax1_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])

w=60/25.4
h=35/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Pyruvate_raw.svg", dpi=900)
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2514296623.py:34: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_10080\2514296623.py:34: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=1, ncols=3)

ax3 = fig.add_subplot(spec[0,:2])
ax3_yield_aux = fig.add_subplot(spec[0,2])
ax3_yield = ax3_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### CO2 plot
############

sns.lineplot(
    data=online_data,
    x="new_feed_time",
    y="Consumed_O2",
    ax=ax3,
    hue="hue",
    # style='Condition',
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    linewidth = 0.5
)

sns.barplot(
    data=data,
    x="Strain",
    y="Yso [mol/molC]",
    errorbar="sd",
    ax=ax3_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax3_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])
ax2.set_xticks([0,20,40,60])
ax3.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])
ax2_yield_aux.set_yticks([])
ax3_yield_aux.set_yticks([])

w=60/25.4
h=35/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Oxygen.svg", dpi=900)

# %%
for variable in offline_data.columns[offline_data.columns.str.contains("net")]:
    
    plt.rcParams['font.size'] = 7
    plt.rcParams.update({'font.sans-serif':'Arial'})
    params = {'mathtext.default': 'regular' }
    plt.rcParams.update(params)

    plt.rcParams['xtick.major.pad']= 2
    plt.rcParams['ytick.major.pad']= 2

    plt.rcParams['axes.labelpad']= 2

    fig = plt.figure(dpi=200)
    spec = fig.add_gridspec(nrows=1, ncols=1)

    ax1 = fig.add_subplot(spec[0,0])

    ### Data curation
    #################

    offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]

    data = offline_data[offline_data["Timepoint (#)"] == "S05"]

    ### CO2 plot
    ############

    sns.lineplot(
        data=offline_data,
        x="average_feed_time",
        y=variable,
        ax=ax1,
        hue="hue",
        style='Condition',
        dashes=[(2, 0)],
        palette="tab20",
        legend=False,
        hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
        errorbar ='sd',
        err_style='bars',
        err_kws = {
            'elinewidth':1.0,
            'capsize':2.0,
        },
        markersize=3,
        markers=['o'],
        markeredgecolor=None,
        linewidth = 1
    )

    ax1.set_xticks([0,20,40,60])

    w=40/25.4
    h=35/25.4
    fig.set_size_inches(w=w,h=h)
    
    # plt.savefig(variable.split(" [")[0]+"_conc.svg")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\999261666.py:28: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\999261666.py:28: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\999261666.py:28: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\999261666.py:28: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\999261666.py:28: UserWarning:
# ...

# %%
for variable in offline_data.columns[offline_data.columns.str.contains("/L")]:
    
    plt.rcParams['font.size'] = 7
    plt.rcParams.update({'font.sans-serif':'Arial'})
    params = {'mathtext.default': 'regular' }
    plt.rcParams.update(params)

    plt.rcParams['xtick.major.pad']= 2
    plt.rcParams['ytick.major.pad']= 2

    plt.rcParams['axes.labelpad']= 2

    fig = plt.figure(dpi=200)
    spec = fig.add_gridspec(nrows=1, ncols=1)

    ax1 = fig.add_subplot(spec[0,0])

    ### Data curation
    #################

    offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]

    data = offline_data[offline_data["Timepoint (#)"] == "S05"]

    ### CO2 plot
    ############

    sns.lineplot(
        data=offline_data,
        x="average_feed_time",
        y=variable,
        ax=ax1,
        hue="hue",
        style='Condition',
        dashes=[(2, 0)],
        palette="tab20",
        legend=False,
        hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
        errorbar ='sd',
        err_style='bars',
        err_kws = {
            'elinewidth':1.0,
            'capsize':2.0,
        },
        markersize=3,
        markers=['o'],
        markeredgecolor=None,
        linewidth = 1
    )

    ax1.set_xticks([0,20,40,60])

    w=40/25.4
    h=35/25.4
    fig.set_size_inches(w=w,h=h)
    
    # plt.savefig(variable.split(" [")[0]+"_conc.svg")
# Out:
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\3045829307.py:28: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\3045829307.py:28: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\3045829307.py:28: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\3045829307.py:28: UserWarning:
# The dashes list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(
# C:\Users\jonas\AppData\Local\Temp\ipykernel_19504\3045829307.py:28: UserWarning:
# ...

# %% [markdown]
# # T test

# %%
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysf [molC/molC]"] = offline_data["net_formic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

# %% [markdown]
# ## Ysx

# %%
variable = "Ysx [molC/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=9.63533758956008, pvalue=0.0006488193466854267)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=9.394225748221062, pvalue=0.0007154709694741075)

# %% [markdown]
# ## Yst

# %%
variable = "Yst [molC/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=7.532718407840222, pvalue=0.0016632847023529858)

# %% [markdown]
# ## Ysc

# %%
variable = "Ysc [molC/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=-12.688004815593215, pvalue=0.00022223056304369174)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=-1.9200860317414887, pvalue=0.12725890054799538)

# %% [markdown]
# ## Yso

# %%
variable = "Yso [mol/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=-4.801666903848145, pvalue=0.008637642192302099)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=-2.6503705830910556, pvalue=0.05695974638357851)

# %% [markdown]
# ## Ysa

# %%
variable = "Ysa [molC/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=-0.3194049355165727, pvalue=0.7654050646890834)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=-8.195745960800298, pvalue=0.001207473208138365)

# %% [markdown]
# ## Ysf

# %%
variable = "Ysf [molC/molC]"
hue_1 = "DDB35:control"
hue_2 = "DDB35:scale-down"
hue_3 = "HMP3071:control"
hue_4 = "HMP3071:scale-down"

group_1 = data[data["hue"] == hue_1][variable]
group_2 = data[data["hue"] == hue_2][variable]
group_3 = data[data["hue"] == hue_3][variable]
group_4 = data[data["hue"] == hue_4][variable]

# %%
scipy.stats.ttest_ind(group_1,group_2)
# Out:
# Ttest_indResult(statistic=-0.2956398864224299, pvalue=0.782217039718494)

# %%
scipy.stats.ttest_ind(group_3,group_4)
# Out:
# Ttest_indResult(statistic=-8.894106062458235, pvalue=0.0008830797988447654)

# %% [markdown]
# # Checking DO

# %%
sns.lineplot(
    data=online_data[online_data["Strain"] == "DDB35"],
    x="new_feed_time",
    hue="hue",
    y="DO",
    palette=[cm.tab20(0), cm.tab20(1)]
)
# Out:
# <Axes: xlabel='new_feed_time', ylabel='DO'>

# %%
for parent_culture in online_data["Parent Culture"].unique():
    
    fig, ax = plt.subplots()
    
    data = online_data[online_data["Parent Culture"] == parent_culture]

    sns.lineplot(
        data=data,
        x="new_feed_time",
        y="DO",
        ax=ax
    )
    
    ax.set_title(parent_culture)

# %%
online_data["hue"]
# Out:
# 0             DDB35:control
# 1             DDB35:control
# 2             DDB35:control
# 3             DDB35:control
# 4             DDB35:control
#                 ...
# 73513    HMP3071:scale-down
# 73514    HMP3071:scale-down
# 73515    HMP3071:scale-down
# 73516    HMP3071:scale-down
# 73517    HMP3071:scale-down
# Name: hue, Length: 73518, dtype: object

# %%
plt.rcParams['font.size'] = 7
plt.rcParams.update({'font.sans-serif':'Arial'})
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.rcParams['xtick.major.pad']= 2
plt.rcParams['ytick.major.pad']= 2

plt.rcParams['axes.labelpad']= 2

fig = plt.figure(dpi=200)
spec = fig.add_gridspec(nrows=2, ncols=4)

ax1 = fig.add_subplot(spec[0,:2])

ax2 = fig.add_subplot(spec[0,2:4])

ax3 = fig.add_subplot(spec[1,:2])
ax3_yield_aux = fig.add_subplot(spec[1,2])
ax3_yield = ax3_yield_aux.twinx()

### Data curation
#################

offline_data["hue"] = offline_data["Strain"]+":"+offline_data["Condition"]
offline_data["Ysx [molC/molC]"] = offline_data["net_biomass_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysc [molC/molC]"] = offline_data["Formed_CO2"]/offline_data["net_glucose_cmol"]
offline_data["Yso [mol/molC]"]  = offline_data["Consumed_O2"]/offline_data["net_glucose_cmol"]
offline_data["Yst [molC/molC]"] = offline_data["net_tryptophan_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysa [molC/molC]"] = offline_data["net_acetic_acid_cmol"]/offline_data["net_glucose_cmol"]
offline_data["Ysp [molC/molC]"] = offline_data["net_pyruvic_acid_cmol"]/offline_data["net_glucose_cmol"]

data = offline_data[offline_data["Timepoint (#)"] == "S05"]

### DO plot 1
#############

sns.lineplot(
    data=online_data[online_data["Strain"] == "DDB35"],
    x="new_feed_time",
    y="DO",
    ax=ax1,
    hue="hue",
    hue_order=["DDB35:scale-down","DDB35:control"],
    palette=[cm.tab20(1), cm.tab20(0)],
    legend=False,
    errorbar ='sd',
    linewidth = 0.5
)

### DO plot 2
#############

sns.lineplot(
    data=online_data[online_data["Strain"] == "HMP3071"],
    x="new_feed_time",
    y="DO",
    ax=ax2,
    hue="hue",
    hue_order=["HMP3071:scale-down","HMP3071:control"],
    palette=[cm.tab20(3), cm.tab20(2)],
    legend=False,
    errorbar ='sd',
    linewidth = 0.5
)

### O2 plot
############

sns.lineplot(
    data=online_data,
    x="new_feed_time",
    y="Consumed_O2",
    ax=ax3,
    hue="hue",
    # style='Condition',
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    linewidth = 0.5
)

### O2 plot
############

sns.lineplot(
    data=online_data,
    x="new_feed_time",
    y="Consumed_O2",
    ax=ax3,
    hue="hue",
    # style='Condition',
    palette="tab20",
    legend=False,
    hue_order=["DDB35:control","DDB35:scale-down","HMP3071:control","HMP3071:scale-down"],
    errorbar ='sd',
    linewidth = 0.5
)

sns.barplot(
    data=data,
    x="Strain",
    y="Yso [mol/molC]",
    errorbar="sd",
    ax=ax3_yield,
    hue="Condition",
    palette="tab20",
    errcolor="k",
    errwidth=1,
    capsize=0.1
)
ax3_yield.get_legend().remove()

ax1.set_xticks([0,20,40,60])
ax2.set_xticks([0,20,40,60])
ax3.set_xticks([0,20,40,60])

ax1_yield_aux.set_yticks([])
ax2_yield_aux.set_yticks([])
ax3_yield_aux.set_yticks([])

w=80/25.4
h=70/25.4
fig.set_size_inches(w=w,h=h)

plt.savefig("Figure_O2_raw.svg", dpi=900)

# %% [markdown]
# # Calling out data

# %% [markdown]
# ## CO2

# %%
data.groupby(["Strain", "Condition"]).mean()[["Formed_CO2"]]
# Out:
#                     Formed_CO2
# Strain  Condition
# DDB35   control       0.469636
#         scale-down    0.529516
# HMP3071 control       0.719104
#         scale-down    0.760960

# %%
data.groupby(["Strain", "Condition"]).std()[["Formed_CO2"]]
# Out:
#                     Formed_CO2
# Strain  Condition
# DDB35   control       0.004415
#         scale-down    0.006755
# HMP3071 control       0.029655
#         scale-down    0.026335

# %% [markdown]
# ## O2

# %%
data.groupby(["Strain", "Condition"]).mean()[["Consumed_O2"]]
# Out:
#                     Consumed_O2
# Strain  Condition
# DDB35   control        0.437746
#         scale-down     0.487565
# HMP3071 control        0.721947
#         scale-down     0.769430

# %%
data.groupby(["Strain", "Condition"]).std()[["Consumed_O2"]]
# Out:
#                     Consumed_O2
# Strain  Condition
# DDB35   control        0.007005
#         scale-down     0.016495
# HMP3071 control        0.016441
#         scale-down     0.026681

# %% [markdown]
# ## Tryptophan

# %%
(0.024884 - 0.013308)/0.024884
# Out:
# 0.4651985211380807

# %%
data.groupby(["Strain", "Condition"]).mean()[["net_tryptophan_cmol"]]
# Out:
#                     net_tryptophan_cmol
# Strain  Condition
# DDB35   control                     NaN
#         scale-down                  NaN
# HMP3071 control                0.024884
#         scale-down             0.013308

# %%
data.groupby(["Strain", "Condition"]).std()[["net_tryptophan_cmol"]]
# Out:
#                     net_tryptophan_cmol
# Strain  Condition
# DDB35   control                     NaN
#         scale-down                  NaN
# HMP3071 control                0.001806
#         scale-down             0.001989

# %% [markdown]
# ## Biomass

# %%
data.groupby(["Strain", "Condition"]).mean()[["net_biomass_cmol"]]
# Out:
#                     net_biomass_cmol
# Strain  Condition
# DDB35   control             0.686751
#         scale-down          0.643975
# HMP3071 control             0.363848
#         scale-down          0.320593

# %%
data.groupby(["Strain", "Condition"]).std()[["net_biomass_cmol"]]
# Out:
#                     net_biomass_cmol
# Strain  Condition
# DDB35   control             0.007001
#         scale-down          0.003296
# HMP3071 control             0.006699
#         scale-down          0.003818

# %% [markdown]
# ## Acetate conc.

# %%
data.groupby(["Strain", "Condition"]).mean()[["acetic acid [g/L]"]]
# Out:
#                     acetic acid [g/L]
# Strain  Condition
# DDB35   control              0.030822
#         scale-down           0.053091
# HMP3071 control              0.853346
#         scale-down           1.402219

# %%
data.groupby(["Strain", "Condition"]).std()[["acetic acid [g/L]"]]
# Out:
#                     acetic acid [g/L]
# Strain  Condition
# DDB35   control              0.053386
#         scale-down           0.091956
# HMP3071 control              0.058787
#         scale-down           0.099787

# %% [markdown]
# ## Acetate

# %%
data.groupby(["Strain", "Condition"]).mean()[["net_acetic_acid_cmol"]]
# Out:
#                     net_acetic_acid_cmol
# Strain  Condition
# DDB35   control                 0.000500
#         scale-down              0.000627
# HMP3071 control                 0.004830
#         scale-down              0.007731

# %%
data.groupby(["Strain", "Condition"]).std()[["net_acetic_acid_cmol"]]
# Out:
#                     net_acetic_acid_cmol
# Strain  Condition
# DDB35   control                 0.000404
#         scale-down              0.000555
# HMP3071 control                 0.000299
#         scale-down              0.000542

# %% [markdown]
# ## Formiate

# %%
data.groupby(["Strain", "Condition"]).mean()[["net_formic_acid_cmol"]]
# Out:
#                     net_formic_acid_cmol
# Strain  Condition
# DDB35   control                 0.000117
#         scale-down              0.000121
# HMP3071 control                 0.002147
#         scale-down              0.003891

# %%
data.groupby(["Strain", "Condition"]).std()[["net_formic_acid_cmol"]]
# Out:
#                     net_formic_acid_cmol
# Strain  Condition
# DDB35   control                 0.000025
#         scale-down              0.000006
# HMP3071 control                 0.000075
#         scale-down              0.000333

# %% [markdown]
# ## Formiate conc.

# %%
data.groupby(["Strain", "Condition"]).mean()[["formic acid [g/L]"]]
# Out:
#                     formic acid [g/L]
# Strain  Condition
# DDB35   control              0.000000
#         scale-down           0.000000
# HMP3071 control              0.586919
#         scale-down           1.088776

# %%
data.groupby(["Strain", "Condition"]).std()[["formic acid [g/L]"]]
# Out:
#                     formic acid [g/L]
# Strain  Condition
# DDB35   control              0.000000
#         scale-down           0.000000
# HMP3071 control              0.022391
#         scale-down           0.095348

# %% [markdown]
# ## Ysx

# %%
data.groupby(["Strain", "Condition"]).mean()[["Ysx [molC/molC]"]]
# Out:
#                     Ysx [molC/molC]
# Strain  Condition
# DDB35   control            0.612985
#         scale-down         0.574709
# HMP3071 control            0.325348
#         scale-down         0.286608

# %%
data.groupby(["Strain", "Condition"]).std()[["Ysx [molC/molC]"]]
# Out:
#                     Ysx [molC/molC]
# Strain  Condition
# DDB35   control            0.006192
#         scale-down         0.003000
# HMP3071 control            0.006437
#         scale-down         0.003097

# %% [markdown]
# ## Ysc

# %%
data.groupby(["Strain", "Condition"]).mean()[["Ysc [molC/molC]"]]
# Out:
#                     Ysc [molC/molC]
# Strain  Condition
# DDB35   control            0.419193
#         scale-down         0.472561
# HMP3071 control            0.642952
#         scale-down         0.680284

# %%
data.groupby(["Strain", "Condition"]).std()[["Ysc [molC/molC]"]]
# Out:
#                     Ysc [molC/molC]
# Strain  Condition
# DDB35   control            0.004191
#         scale-down         0.005959
# HMP3071 control            0.024594
#         scale-down         0.023005

# %% [markdown]
# ## Yso

# %%
data.groupby(["Strain", "Condition"]).mean()[["Yso [mol/molC]"]]
# Out:
#                     Yso [mol/molC]
# Strain  Condition
# DDB35   control           0.390727
#         scale-down        0.435123
# HMP3071 control           0.645522
#         scale-down        0.687881

# %%
data.groupby(["Strain", "Condition"]).std()[["Yso [mol/molC]"]]
# Out:
#                     Yso [mol/molC]
# Strain  Condition
# DDB35   control           0.006270
#         scale-down        0.014736
# HMP3071 control           0.013143
#         scale-down        0.024363

# %% [markdown]
# ## Ysa

# %%
data.groupby(["Strain", "Condition"]).mean()[["Ysa [molC/molC]"]]
# Out:
#                     Ysa [molC/molC]
# Strain  Condition
# DDB35   control            0.000447
#         scale-down         0.000560
# HMP3071 control            0.004318
#         scale-down         0.006912

# %%
data.groupby(["Strain", "Condition"]).std()[["Ysa [molC/molC]"]]
# Out:
#                     Ysa [molC/molC]
# Strain  Condition
# DDB35   control            0.000361
#         scale-down         0.000495
# HMP3071 control            0.000258
#         scale-down         0.000484

# %% [markdown]
# ## Ysf

# %%
data.groupby(["Strain", "Condition"]).mean()[["Ysf [molC/molC]"]]
# Out:
#                     Ysf [molC/molC]
# Strain  Condition
# DDB35   control            0.000104
#         scale-down         0.000108
# HMP3071 control            0.001920
#         scale-down         0.003479

# %%
data.groupby(["Strain", "Condition"]).std()[["Ysf [molC/molC]"]]
# Out:
#                     Ysf [molC/molC]
# Strain  Condition
# DDB35   control            0.000023
#         scale-down         0.000005
# HMP3071 control            0.000062
#         scale-down         0.000297

# %% [markdown]
# ## Yst

# %%
data.groupby(["Strain", "Condition"]).mean()[["Yst [molC/molC]"]]
# Out:
#                     Yst [molC/molC]
# Strain  Condition
# DDB35   control                 NaN
#         scale-down              NaN
# HMP3071 control            0.022249
#         scale-down         0.011899

# %%
data.groupby(["Strain", "Condition"]).std()[["Yst [molC/molC]"]]
# Out:
#                     Yst [molC/molC]
# Strain  Condition
# DDB35   control                 NaN
#         scale-down              NaN
# HMP3071 control            0.001572
#         scale-down         0.001786

# %%
np.log10(1e-50)
# Out:
# -50.0

# %%
-np.log10(1e-50)
# Out:
# 50.0
